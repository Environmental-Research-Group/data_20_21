# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

riders2013 = pd.read_csv("2013riders_bymonth.csv")
riders2014 = pd.read_csv("2014riders_bymonth.csv")
riders2015 = pd.read_csv("2015riders_bymonth.csv")
riders2016 = pd.read_csv("2016riders_bymonth.csv")
riders2017 = pd.read_csv("2017riders_bymonth.csv")
riders2018 = pd.read_csv("2018riders_bymonth.csv")
riders2019 = pd.read_csv("2019riders_bymonth.csv")
riders2020 = pd.read_csv("2020riders_bymonth.csv")

allrides = pd.read_csv("station_month_year_riders.csv")

riders = {2013: riders2013, 2014: riders2014, 2015: riders2015, 2016: riders2016, 2017: riders2017, 2018: riders2018, 2019: riders2019}
#print(riders[2013][(riders[2013]['stationame'] == '18th')])

# %%
for station in riders2020['stationame']:
    for month in range(1,13):
        for year in range(2013,2020):
            ridership = riders[year][(riders[year]['stationame'] == station)][str(month)].astype(int)
            print(station, year, month, ridership)
# Out:
# 18th 2013 1 0    45209
# Name: 1, dtype: int64
# 18th 2014 1 0    46217
# Name: 1, dtype: int64
# 18th 2015 1 0    47085
# Name: 1, dtype: int64
# 18th 2016 1 0    46937
# Name: 1, dtype: int64
# 18th 2017 1 0    43545
# Name: 1, dtype: int64
# 18th 2018 1 0    41483
# Name: 1, dtype: int64
# 18th 2019 1 0    37774
# Name: 1, dtype: int64
# 18th 2013 2 0    43826
# Name: 2, dtype: int64
# 18th 2014 2 0    48018
# Name: 2, dtype: int64
# 18th 2015 2 0    47687
# Name: 2, dtype: int64
# 18th 2016 2 0    48592
# Name: 2, dtype: int64
# 18th 2017 2 0    44012
# Name: 2, dtype: int64
# 18th 2018 2 0    39947
# Name: 2, dtype: int64
# 18th 2019 2 0    39459
# Name: 2, dtype: int64
# 18th 2013 3 0    46890
# Name: 3, dtype: int64
# 18th 2014 3 0    54695
# Name: 3, dtype: int64
# 18th 2015 3 0    55931
# Name: 3, dtype: int64
# 18th 2016 3 0    53150
# Name: 3, dtype: int64
# 18th 2017 3 0    49918
# Name: 3, dtype: int64
# 18th 2018 3 0    47031
# Name: 3, dtype: int64
# 18th 2019 3 0    44800
# Name: 3, dtype: int64
# 18th 2013 4 0    49225
# Name: 4, dtype: int64
# 18th 2014 4 0    54155
# Name: 4, dtype: int64
# 18th 2015 4 0    55871
# Name: 4, dtype: int64
# 18th 2016 4 0    49230
# Name: 4, dtype: int64
# 18th 2017 4 0    47984
# Name: 4, dtype: int64
# 18th 2018 4 0    45078
# Name: 4, dtype: int64
# 18th 2019 4 0    46330
# Name: 4, dtype: int64
# 18th 2013 5 0    49580
# Name: 5, dtype: int64
# 18th 2014 5 0    53650
# Name: 5, dtype: int64
# 18th 2015 5 0    56885
# Name: 5, dtype: int64
# 18th 2016 5 0    53193
# Name: 5, dtype: int64
# 18th 2017 5 0    51968
# Name: 5, dtype: int64
# 18th 2018 5 0    50403
# Name: 5, dtype: int64
# 18th 2019 5 0    50367
# Name: 5, dtype: int64
# 18th 2013 6 0    49315
# Name: 6, dtype: int64
# 18th 2014 6 0    51491
# Name: 6, dtype: int64
# 18th 2015 6 0    55444
# Name: 6, dtype: int64
# 18th 2016 6 0    55314
# Name: 6, dtype: int64
# 18th 2017 6 0    54815
# Name: 6, dtype: int64
# 18th 2018 6 0    52183
# Name: 6, dtype: int64
# 18th 2019 6 0    46218
# Name: 6, dtype: int64
# 18th 2013 7 0    52531
# Name: 7, dtype: int64
# 18th 2014 7 0    54550
# Name: 7, dtype: int64
# 18th 2015 7 0    57032
# Name: 7, dtype: int64
# 18th 2016 7 0    51916
# Name: 7, dtype: int64
# 18th 2017 7 0    49672
# Name: 7, dtype: int64
# 18th 2018 7 0    49160
# Name: 7, dtype: int64
# 18th 2019 7 0    48394
# Name: 7, dtype: int64
# 18th 2013 8 0    53121
# Name: 8, dtype: int64
# 18th 2014 8 0    52930
# Name: 8, dtype: int64
# 18th 2015 8 0    54435
# Name: 8, dtype: int64
# 18th 2016 8 0    51504
# Name: 8, dtype: int64
# 18th 2017 8 0    50610
# Name: 8, dtype: int64
# 18th 2018 8 0    0
# Name: 8, dtype: int64
# 18th 2019 8 0    48968
# Name: 8, dtype: int64
# 18th 2013 9 0    52430
# Name: 9, dtype: int64
# 18th 2014 9 0    56674
# Name: 9, dtype: int64
# 18th 2015 9 0    59917
# Name: 9, dtype: int64
# 18th 2016 9 0    53657
# Name: 9, dtype: int64
# 18th 2017 9 0    52100
# Name: 9, dtype: int64
# 18th 2018 9 0    0
# Name: 9, dtype: int64
# 18th 2019 9 0    48349
# Name: 9, dtype: int64
# 18th 2013 10 0    59578
# Name: 10, dtype: int64
# 18th 2014 10 0    63062
# Name: 10, dtype: int64
# 18th 2015 10 0    62697
# Name: 10, dtype: int64
# 18th 2016 10 0    57029
# Name: 10, dtype: int64
# 18th 2017 10 0    54559
# Name: 10, dtype: int64
# 18th 2018 10 0    0
# Name: 10, dtype: int64
# 18th 2019 10 0    53567
# Name: 10, dtype: int64
# 18th 2013 11 0    50809
# Name: 11, dtype: int64
# 18th 2014 11 0    52543
# Name: 11, dtype: int64
# 18th 2015 11 0    54028
# Name: 11, dtype: int64
# 18th 2016 11 0    50206
# Name: 11, dtype: int64
# 18th 2017 11 0    47590
# Name: 11, dtype: int64
# 18th 2018 11 0    0
# Name: 11, dtype: int64
# 18th 2019 11 0    45109
# Name: 11, dtype: int64
# 18th 2013 12 0    46140
# Name: 12, dtype: int64
# 18th 2014 12 0    48912
# Name: 12, dtype: int64
# 18th 2015 12 0    49585
# Name: 12, dtype: int64
# 18th 2016 12 0    42987
# Name: 12, dtype: int64
# 18th 2017 12 0    41491
# Name: 12, dtype: int64
# 18th 2018 12 0    0
# Name: 12, dtype: int64
# 18th 2019 12 0    40754
# Name: 12, dtype: int64
# 35-Bronzeville-IIT 2013 1 1    54802
# Name: 1, dtype: int64
# 35-Bronzeville-IIT 2014 1 1    53326
# Name: 1, dtype: int64
# 35-Bronzeville-IIT 2015 1 1    50498
# Name: 1, dtype: int64
# 35-Bronzeville-IIT 2016 1 1    46246
# Name: 1, dtype: int64
# 35-Bronzeville-IIT 2017 1 1    41734
# Name: 1, dtype: int64
# 35-Bronzeville-IIT 2018 1 1    41031
# Name: 1, dtype: int64
# 35-Bronzeville-IIT 2019 1 1    34814
# Name: 1, dtype: int64
# 35-Bronzeville-IIT 2013 2 1    55037
# Name: 2, dtype: int64
# 35-Bronzeville-IIT 2014 2 1    57402
# Name: 2, dtype: int64
# 35-Bronzeville-IIT 2015 2 1    48235
# Name: 2, dtype: int64
# 35-Bronzeville-IIT 2016 2 1    48582
# Name: 2, dtype: int64
# 35-Bronzeville-IIT 2017 2 1    42972
# Name: 2, dtype: int64
# 35-Bronzeville-IIT 2018 2 1    39340
# Name: 2, dtype: int64
# 35-Bronzeville-IIT 2019 2 1    38677
# Name: 2, dtype: int64
# 35-Bronzeville-IIT 2013 3 1    57203
# Name: 3, dtype: int64
# 35-Bronzeville-IIT 2014 3 1    63458
# Name: 3, dtype: int64
# 35-Bronzeville-IIT 2015 3 1    56524
# Name: 3, dtype: int64
# 35-Bronzeville-IIT 2016 3 1    50802
# Name: 3, dtype: int64
# 35-Bronzeville-IIT 2017 3 1    45725
# Name: 3, dtype: int64
# 35-Bronzeville-IIT 2018 3 1    42824
# Name: 3, dtype: int64
# 35-Bronzeville-IIT 2019 3 1    42182
# Name: 3, dtype: int64
# 35-Bronzeville-IIT 2013 4 1    62132
# Name: 4, dtype: int64
# 35-Bronzeville-IIT 2014 4 1    63541
# Name: 4, dtype: int64
# 35-Bronzeville-IIT 2015 4 1    56650
# Name: 4, dtype: int64
# 35-Bronzeville-IIT 2016 4 1    49316
# Name: 4, dtype: int64
# 35-Bronzeville-IIT 2017 4 1    44256
# Name: 4, dtype: int64
# 35-Bronzeville-IIT 2018 4 1    42437
# Name: 4, dtype: int64
# 35-Bronzeville-IIT 2019 4 1    42988
# Name: 4, dtype: int64
# 35-Bronzeville-IIT 2013 5 1    96994
# Name: 5, dtype: int64
# 35-Bronzeville-IIT 2014 5 1    57731
# Name: 5, dtype: int64
# 35-Bronzeville-IIT 2015 5 1    53901
# Name: 5, dtype: int64
# 35-Bronzeville-IIT 2016 5 1    46756
# Name: 5, dtype: int64
# 35-Bronzeville-IIT 2017 5 1    41680
# Name: 5, dtype: int64
# 35-Bronzeville-IIT 2018 5 1    41393
# Name: 5, dtype: int64
# 35-Bronzeville-IIT 2019 5 1    40079
# Name: 5, dtype: int64
# 35-Bronzeville-IIT 2013 6 1    135871
# Name: 6, dtype: int64
# 35-Bronzeville-IIT 2014 6 1    51875
# Name: 6, dtype: int64
# 35-Bronzeville-IIT 2015 6 1    55671
# Name: 6, dtype: int64
# 35-Bronzeville-IIT 2016 6 1    46254
# Name: 6, dtype: int64
# 35-Bronzeville-IIT 2017 6 1    41701
# Name: 6, dtype: int64
# 35-Bronzeville-IIT 2018 6 1    39895
# Name: 6, dtype: int64
# 35-Bronzeville-IIT 2019 6 1    31349
# Name: 6, dtype: int64
# 35-Bronzeville-IIT 2013 7 1    163900
# Name: 7, dtype: int64
# 35-Bronzeville-IIT 2014 7 1    55254
# Name: 7, dtype: int64
# 35-Bronzeville-IIT 2015 7 1    58436
# Name: 7, dtype: int64
# 35-Bronzeville-IIT 2016 7 1    46453
# Name: 7, dtype: int64
# 35-Bronzeville-IIT 2017 7 1    40078
# Name: 7, dtype: int64
# 35-Bronzeville-IIT 2018 7 1    41052
# Name: 7, dtype: int64
# 35-Bronzeville-IIT 2019 7 1    42534
# Name: 7, dtype: int64
# 35-Bronzeville-IIT 2013 8 1    178602
# Name: 8, dtype: int64
# 35-Bronzeville-IIT 2014 8 1    59190
# Name: 8, dtype: int64
# 35-Bronzeville-IIT 2015 8 1    56667
# Name: 8, dtype: int64
# 35-Bronzeville-IIT 2016 8 1    48353
# Name: 8, dtype: int64
# 35-Bronzeville-IIT 2017 8 1    49505
# Name: 8, dtype: int64
# 35-Bronzeville-IIT 2018 8 1    0
# Name: 8, dtype: int64
# 35-Bronzeville-IIT 2019 8 1    46716
# Name: 8, dtype: int64
# 35-Bronzeville-IIT 2013 9 1    174381
# Name: 9, dtype: int64
# 35-Bronzeville-IIT 2014 9 1    67369
# Name: 9, dtype: int64
# 35-Bronzeville-IIT 2015 9 1    63203
# Name: 9, dtype: int64
# 35-Bronzeville-IIT 2016 9 1    55974
# Name: 9, dtype: int64
# 35-Bronzeville-IIT 2017 9 1    54569
# Name: 9, dtype: int64
# 35-Bronzeville-IIT 2018 9 1    0
# Name: 9, dtype: int64
# 35-Bronzeville-IIT 2019 9 1    48386
# Name: 9, dtype: int64
# 35-Bronzeville-IIT 2013 10 1    138550
# Name: 10, dtype: int64
# 35-Bronzeville-IIT 2014 10 1    71437
# Name: 10, dtype: int64
# 35-Bronzeville-IIT 2015 10 1    66603
# Name: 10, dtype: int64
# 35-Bronzeville-IIT 2016 10 1    55499
# Name: 10, dtype: int64
# 35-Bronzeville-IIT 2017 10 1    56328
# Name: 10, dtype: int64
# 35-Bronzeville-IIT 2018 10 1    0
# Name: 10, dtype: int64
# 35-Bronzeville-IIT 2019 10 1    47505
# Name: 10, dtype: int64
# 35-Bronzeville-IIT 2013 11 1    62687
# Name: 11, dtype: int64
# 35-Bronzeville-IIT 2014 11 1    53033
# Name: 11, dtype: int64
# 35-Bronzeville-IIT 2015 11 1    54643
# Name: 11, dtype: int64
# 35-Bronzeville-IIT 2016 11 1    49688
# Name: 11, dtype: int64
# 35-Bronzeville-IIT 2017 11 1    48257
# Name: 11, dtype: int64
# 35-Bronzeville-IIT 2018 11 1    0
# Name: 11, dtype: int64
# 35-Bronzeville-IIT 2019 11 1    37047
# Name: 11, dtype: int64
# 35-Bronzeville-IIT 2013 12 1    49905
# Name: 12, dtype: int64
# 35-Bronzeville-IIT 2014 12 1    49081
# Name: 12, dtype: int64
# 35-Bronzeville-IIT 2015 12 1    45153
# Name: 12, dtype: int64
# 35-Bronzeville-IIT 2016 12 1    36205
# Name: 12, dtype: int64
# 35-Bronzeville-IIT 2017 12 1    35603
# Name: 12, dtype: int64
# 35-Bronzeville-IIT 2018 12 1    0
# Name: 12, dtype: int64
# 35-Bronzeville-IIT 2019 12 1    28402
# Name: 12, dtype: int64
# 35th/Archer 2013 1 2    69894
# Name: 1, dtype: int64
# 35th/Archer 2014 1 2    67981
# Name: 1, dtype: int64
# 35th/Archer 2015 1 2    70724
# Name: 1, dtype: int64
# 35th/Archer 2016 1 2    72756
# Name: 1, dtype: int64
# 35th/Archer 2017 1 2    70638
# Name: 1, dtype: int64
# 35th/Archer 2018 1 2    69728
# Name: 1, dtype: int64
# 35th/Archer 2019 1 2    63280
# Name: 1, dtype: int64
# 35th/Archer 2013 2 2    66850
# Name: 2, dtype: int64
# 35th/Archer 2014 2 2    70977
# Name: 2, dtype: int64
# 35th/Archer 2015 2 2    68041
# Name: 2, dtype: int64
# 35th/Archer 2016 2 2    77541
# Name: 2, dtype: int64
# 35th/Archer 2017 2 2    73442
# Name: 2, dtype: int64
# 35th/Archer 2018 2 2    67494
# Name: 2, dtype: int64
# 35th/Archer 2019 2 2    65831
# Name: 2, dtype: int64
# 35th/Archer 2013 3 2    73422
# Name: 3, dtype: int64
# 35th/Archer 2014 3 2    81543
# Name: 3, dtype: int64
# 35th/Archer 2015 3 2    81146
# Name: 3, dtype: int64
# 35th/Archer 2016 3 2    85958
# Name: 3, dtype: int64
# 35th/Archer 2017 3 2    83818
# Name: 3, dtype: int64
# 35th/Archer 2018 3 2    76222
# Name: 3, dtype: int64
# 35th/Archer 2019 3 2    74550
# Name: 3, dtype: int64
# 35th/Archer 2013 4 2    77511
# Name: 4, dtype: int64
# 35th/Archer 2014 4 2    81260
# Name: 4, dtype: int64
# 35th/Archer 2015 4 2    80490
# Name: 4, dtype: int64
# 35th/Archer 2016 4 2    82980
# Name: 4, dtype: int64
# 35th/Archer 2017 4 2    76057
# Name: 4, dtype: int64
# 35th/Archer 2018 4 2    75824
# Name: 4, dtype: int64
# 35th/Archer 2019 4 2    74935
# Name: 4, dtype: int64
# 35th/Archer 2013 5 2    80904
# Name: 5, dtype: int64
# 35th/Archer 2014 5 2    78749
# Name: 5, dtype: int64
# 35th/Archer 2015 5 2    81240
# Name: 5, dtype: int64
# 35th/Archer 2016 5 2    84890
# Name: 5, dtype: int64
# 35th/Archer 2017 5 2    82899
# Name: 5, dtype: int64
# 35th/Archer 2018 5 2    81501
# Name: 5, dtype: int64
# 35th/Archer 2019 5 2    79585
# Name: 5, dtype: int64
# 35th/Archer 2013 6 2    77753
# Name: 6, dtype: int64
# 35th/Archer 2014 6 2    77871
# Name: 6, dtype: int64
# 35th/Archer 2015 6 2    84193
# Name: 6, dtype: int64
# 35th/Archer 2016 6 2    84871
# Name: 6, dtype: int64
# 35th/Archer 2017 6 2    81646
# Name: 6, dtype: int64
# 35th/Archer 2018 6 2    77181
# Name: 6, dtype: int64
# 35th/Archer 2019 6 2    74129
# Name: 6, dtype: int64
# 35th/Archer 2013 7 2    79670
# Name: 7, dtype: int64
# 35th/Archer 2014 7 2    78852
# Name: 7, dtype: int64
# 35th/Archer 2015 7 2    87497
# Name: 7, dtype: int64
# 35th/Archer 2016 7 2    80998
# Name: 7, dtype: int64
# 35th/Archer 2017 7 2    77983
# Name: 7, dtype: int64
# 35th/Archer 2018 7 2    0
# Name: 7, dtype: int64
# 35th/Archer 2019 7 2    76951
# Name: 7, dtype: int64
# 35th/Archer 2013 8 2    82437
# Name: 8, dtype: int64
# 35th/Archer 2014 8 2    77772
# Name: 8, dtype: int64
# 35th/Archer 2015 8 2    83949
# Name: 8, dtype: int64
# 35th/Archer 2016 8 2    83149
# Name: 8, dtype: int64
# 35th/Archer 2017 8 2    83948
# Name: 8, dtype: int64
# 35th/Archer 2018 8 2    0
# Name: 8, dtype: int64
# 35th/Archer 2019 8 2    77527
# Name: 8, dtype: int64
# 35th/Archer 2013 9 2    85328
# Name: 9, dtype: int64
# 35th/Archer 2014 9 2    84155
# Name: 9, dtype: int64
# 35th/Archer 2015 9 2    90541
# Name: 9, dtype: int64
# 35th/Archer 2016 9 2    87731
# Name: 9, dtype: int64
# 35th/Archer 2017 9 2    86364
# Name: 9, dtype: int64
# 35th/Archer 2018 9 2    0
# Name: 9, dtype: int64
# 35th/Archer 2019 9 2    82115
# Name: 9, dtype: int64
# 35th/Archer 2013 10 2    92030
# Name: 10, dtype: int64
# 35th/Archer 2014 10 2    89597
# Name: 10, dtype: int64
# 35th/Archer 2015 10 2    94119
# Name: 10, dtype: int64
# 35th/Archer 2016 10 2    89009
# Name: 10, dtype: int64
# 35th/Archer 2017 10 2    88874
# Name: 10, dtype: int64
# 35th/Archer 2018 10 2    0
# Name: 10, dtype: int64
# 35th/Archer 2019 10 2    86984
# Name: 10, dtype: int64
# 35th/Archer 2013 11 2    78341
# Name: 11, dtype: int64
# 35th/Archer 2014 11 2    73777
# Name: 11, dtype: int64
# 35th/Archer 2015 11 2    81983
# Name: 11, dtype: int64
# 35th/Archer 2016 11 2    83563
# Name: 11, dtype: int64
# 35th/Archer 2017 11 2    80665
# Name: 11, dtype: int64
# 35th/Archer 2018 11 2    0
# Name: 11, dtype: int64
# 35th/Archer 2019 11 2    73498
# Name: 11, dtype: int64
# 35th/Archer 2013 12 2    72051
# Name: 12, dtype: int64
# 35th/Archer 2014 12 2    74131
# Name: 12, dtype: int64
# 35th/Archer 2015 12 2    79175
# Name: 12, dtype: int64
# 35th/Archer 2016 12 2    71010
# Name: 12, dtype: int64
# 35th/Archer 2017 12 2    69860
# Name: 12, dtype: int64
# 35th/Archer 2018 12 2    0
# Name: 12, dtype: int64
# 35th/Archer 2019 12 2    66907
# Name: 12, dtype: int64
# 43rd 2013 1 3    25400
# Name: 1, dtype: int64
# 43rd 2014 1 3    26652
# Name: 1, dtype: int64
# 43rd 2015 1 3    25034
# Name: 1, dtype: int64
# 43rd 2016 1 3    26151
# Name: 1, dtype: int64
# 43rd 2017 1 3    23998
# Name: 1, dtype: int64
# 43rd 2018 1 3    23610
# Name: 1, dtype: int64
# 43rd 2019 1 3    20798
# Name: 1, dtype: int64
# 43rd 2013 2 3    24122
# Name: 2, dtype: int64
# 43rd 2014 2 3    27161
# Name: 2, dtype: int64
# 43rd 2015 2 3    23378
# Name: 2, dtype: int64
# 43rd 2016 2 3    26168
# Name: 2, dtype: int64
# 43rd 2017 2 3    23378
# Name: 2, dtype: int64
# 43rd 2018 2 3    22349
# Name: 2, dtype: int64
# 43rd 2019 2 3    21026
# Name: 2, dtype: int64
# 43rd 2013 3 3    25631
# Name: 3, dtype: int64
# 43rd 2014 3 3    30873
# Name: 3, dtype: int64
# 43rd 2015 3 3    27802
# Name: 3, dtype: int64
# 43rd 2016 3 3    28258
# Name: 3, dtype: int64
# 43rd 2017 3 3    25852
# Name: 3, dtype: int64
# 43rd 2018 3 3    24658
# Name: 3, dtype: int64
# 43rd 2019 3 3    22658
# Name: 3, dtype: int64
# 43rd 2013 4 3    28026
# Name: 4, dtype: int64
# 43rd 2014 4 3    30499
# Name: 4, dtype: int64
# 43rd 2015 4 3    28122
# Name: 4, dtype: int64
# 43rd 2016 4 3    26313
# Name: 4, dtype: int64
# 43rd 2017 4 3    24494
# Name: 4, dtype: int64
# 43rd 2018 4 3    24843
# Name: 4, dtype: int64
# 43rd 2019 4 3    23119
# Name: 4, dtype: int64
# 43rd 2013 5 3    33028
# Name: 5, dtype: int64
# 43rd 2014 5 3    31469
# Name: 5, dtype: int64
# 43rd 2015 5 3    29182
# Name: 5, dtype: int64
# 43rd 2016 5 3    28594
# Name: 5, dtype: int64
# 43rd 2017 5 3    27021
# Name: 5, dtype: int64
# 43rd 2018 5 3    27796
# Name: 5, dtype: int64
# 43rd 2019 5 3    25185
# Name: 5, dtype: int64
# 43rd 2013 6 3    38924
# Name: 6, dtype: int64
# 43rd 2014 6 3    29751
# Name: 6, dtype: int64
# 43rd 2015 6 3    30991
# Name: 6, dtype: int64
# 43rd 2016 6 3    29016
# Name: 6, dtype: int64
# 43rd 2017 6 3    28392
# Name: 6, dtype: int64
# 43rd 2018 6 3    27308
# Name: 6, dtype: int64
# 43rd 2019 6 3    24711
# Name: 6, dtype: int64
# 43rd 2013 7 3    42997
# Name: 7, dtype: int64
# 43rd 2014 7 3    33066
# Name: 7, dtype: int64
# 43rd 2015 7 3    33242
# Name: 7, dtype: int64
# 43rd 2016 7 3    28917
# Name: 7, dtype: int64
# 43rd 2017 7 3    27975
# Name: 7, dtype: int64
# 43rd 2018 7 3    28420
# Name: 7, dtype: int64
# 43rd 2019 7 3    26747
# Name: 7, dtype: int64
# 43rd 2013 8 3    45461
# Name: 8, dtype: int64
# 43rd 2014 8 3    33108
# Name: 8, dtype: int64
# 43rd 2015 8 3    32592
# Name: 8, dtype: int64
# 43rd 2016 8 3    30370
# Name: 8, dtype: int64
# 43rd 2017 8 3    29815
# Name: 8, dtype: int64
# 43rd 2018 8 3    0
# Name: 8, dtype: int64
# 43rd 2019 8 3    26441
# Name: 8, dtype: int64
# 43rd 2013 9 3    44917
# Name: 9, dtype: int64
# 43rd 2014 9 3    32200
# Name: 9, dtype: int64
# 43rd 2015 9 3    31778
# Name: 9, dtype: int64
# 43rd 2016 9 3    29097
# Name: 9, dtype: int64
# 43rd 2017 9 3    28105
# Name: 9, dtype: int64
# 43rd 2018 9 3    0
# Name: 9, dtype: int64
# 43rd 2019 9 3    25280
# Name: 9, dtype: int64
# 43rd 2013 10 3    44413
# Name: 10, dtype: int64
# 43rd 2014 10 3    33249
# Name: 10, dtype: int64
# 43rd 2015 10 3    33748
# Name: 10, dtype: int64
# 43rd 2016 10 3    29734
# Name: 10, dtype: int64
# 43rd 2017 10 3    29156
# Name: 10, dtype: int64
# 43rd 2018 10 3    0
# Name: 10, dtype: int64
# 43rd 2019 10 3    26804
# Name: 10, dtype: int64
# 43rd 2013 11 3    30701
# Name: 11, dtype: int64
# 43rd 2014 11 3    27083
# Name: 11, dtype: int64
# 43rd 2015 11 3    29574
# Name: 11, dtype: int64
# 43rd 2016 11 3    27136
# Name: 11, dtype: int64
# 43rd 2017 11 3    25764
# Name: 11, dtype: int64
# 43rd 2018 11 3    0
# Name: 11, dtype: int64
# 43rd 2019 11 3    21558
# Name: 11, dtype: int64
# 43rd 2013 12 3    28678
# Name: 12, dtype: int64
# 43rd 2014 12 3    28172
# Name: 12, dtype: int64
# 43rd 2015 12 3    28842
# Name: 12, dtype: int64
# 43rd 2016 12 3    23745
# Name: 12, dtype: int64
# 43rd 2017 12 3    24280
# Name: 12, dtype: int64
# 43rd 2018 12 3    0
# Name: 12, dtype: int64
# 43rd 2019 12 3    21089
# Name: 12, dtype: int64
# 47th-Dan Ryan 2013 1 4    79341
# Name: 1, dtype: int64
# 47th-Dan Ryan 2014 1 4    64771
# Name: 1, dtype: int64
# 47th-Dan Ryan 2015 1 4    82257
# Name: 1, dtype: int64
# 47th-Dan Ryan 2016 1 4    81853
# Name: 1, dtype: int64
# 47th-Dan Ryan 2017 1 4    74650
# Name: 1, dtype: int64
# 47th-Dan Ryan 2018 1 4    71256
# Name: 1, dtype: int64
# 47th-Dan Ryan 2019 1 4    63395
# Name: 1, dtype: int64
# 47th-Dan Ryan 2013 2 4    73431
# Name: 2, dtype: int64
# 47th-Dan Ryan 2014 2 4    70644
# Name: 2, dtype: int64
# 47th-Dan Ryan 2015 2 4    75432
# Name: 2, dtype: int64
# 47th-Dan Ryan 2016 2 4    82189
# Name: 2, dtype: int64
# 47th-Dan Ryan 2017 2 4    72555
# Name: 2, dtype: int64
# 47th-Dan Ryan 2018 2 4    66707
# Name: 2, dtype: int64
# 47th-Dan Ryan 2019 2 4    64104
# Name: 2, dtype: int64
# 47th-Dan Ryan 2013 3 4    80169
# Name: 3, dtype: int64
# 47th-Dan Ryan 2014 3 4    83505
# Name: 3, dtype: int64
# 47th-Dan Ryan 2015 3 4    90736
# Name: 3, dtype: int64
# 47th-Dan Ryan 2016 3 4    90425
# Name: 3, dtype: int64
# 47th-Dan Ryan 2017 3 4    82190
# Name: 3, dtype: int64
# 47th-Dan Ryan 2018 3 4    76065
# Name: 3, dtype: int64
# 47th-Dan Ryan 2019 3 4    70660
# Name: 3, dtype: int64
# 47th-Dan Ryan 2013 4 4    81340
# Name: 4, dtype: int64
# 47th-Dan Ryan 2014 4 4    83779
# Name: 4, dtype: int64
# 47th-Dan Ryan 2015 4 4    89883
# Name: 4, dtype: int64
# 47th-Dan Ryan 2016 4 4    86137
# Name: 4, dtype: int64
# 47th-Dan Ryan 2017 4 4    76694
# Name: 4, dtype: int64
# 47th-Dan Ryan 2018 4 4    74971
# Name: 4, dtype: int64
# 47th-Dan Ryan 2019 4 4    69705
# Name: 4, dtype: int64
# 47th-Dan Ryan 2013 5 4    48346
# Name: 5, dtype: int64
# 47th-Dan Ryan 2014 5 4    90626
# Name: 5, dtype: int64
# 47th-Dan Ryan 2015 5 4    94329
# Name: 5, dtype: int64
# 47th-Dan Ryan 2016 5 4    91301
# Name: 5, dtype: int64
# 47th-Dan Ryan 2017 5 4    85109
# Name: 5, dtype: int64
# 47th-Dan Ryan 2018 5 4    82719
# Name: 5, dtype: int64
# 47th-Dan Ryan 2019 5 4    76269
# Name: 5, dtype: int64
# 47th-Dan Ryan 2013 6 4    0
# Name: 6, dtype: int64
# 47th-Dan Ryan 2014 6 4    85967
# Name: 6, dtype: int64
# 47th-Dan Ryan 2015 6 4    93706
# Name: 6, dtype: int64
# 47th-Dan Ryan 2016 6 4    88804
# Name: 6, dtype: int64
# 47th-Dan Ryan 2017 6 4    85830
# Name: 6, dtype: int64
# 47th-Dan Ryan 2018 6 4    79548
# Name: 6, dtype: int64
# 47th-Dan Ryan 2019 6 4    73560
# Name: 6, dtype: int64
# 47th-Dan Ryan 2013 7 4    0
# Name: 7, dtype: int64
# 47th-Dan Ryan 2014 7 4    91203
# Name: 7, dtype: int64
# 47th-Dan Ryan 2015 7 4    97163
# Name: 7, dtype: int64
# 47th-Dan Ryan 2016 7 4    89895
# Name: 7, dtype: int64
# 47th-Dan Ryan 2017 7 4    72155
# Name: 7, dtype: int64
# 47th-Dan Ryan 2018 7 4    80330
# Name: 7, dtype: int64
# 47th-Dan Ryan 2019 7 4    78151
# Name: 7, dtype: int64
# 47th-Dan Ryan 2013 8 4    0
# Name: 8, dtype: int64
# 47th-Dan Ryan 2014 8 4    89002
# Name: 8, dtype: int64
# 47th-Dan Ryan 2015 8 4    93622
# Name: 8, dtype: int64
# 47th-Dan Ryan 2016 8 4    88842
# Name: 8, dtype: int64
# 47th-Dan Ryan 2017 8 4    64510
# Name: 8, dtype: int64
# 47th-Dan Ryan 2018 8 4    0
# Name: 8, dtype: int64
# 47th-Dan Ryan 2019 8 4    79400
# Name: 8, dtype: int64
# 47th-Dan Ryan 2013 9 4    25643
# Name: 9, dtype: int64
# 47th-Dan Ryan 2014 9 4    96234
# Name: 9, dtype: int64
# 47th-Dan Ryan 2015 9 4    96044
# Name: 9, dtype: int64
# 47th-Dan Ryan 2016 9 4    90233
# Name: 9, dtype: int64
# 47th-Dan Ryan 2017 9 4    61712
# Name: 9, dtype: int64
# 47th-Dan Ryan 2018 9 4    0
# Name: 9, dtype: int64
# 47th-Dan Ryan 2019 9 4    76728
# Name: 9, dtype: int64
# 47th-Dan Ryan 2013 10 4    68632
# Name: 10, dtype: int64
# 47th-Dan Ryan 2014 10 4    101814
# Name: 10, dtype: int64
# 47th-Dan Ryan 2015 10 4    101988
# Name: 10, dtype: int64
# 47th-Dan Ryan 2016 10 4    92876
# Name: 10, dtype: int64
# 47th-Dan Ryan 2017 10 4    83468
# Name: 10, dtype: int64
# 47th-Dan Ryan 2018 10 4    0
# Name: 10, dtype: int64
# 47th-Dan Ryan 2019 10 4    78389
# Name: 10, dtype: int64
# 47th-Dan Ryan 2013 11 4    69155
# Name: 11, dtype: int64
# 47th-Dan Ryan 2014 11 4    90034
# Name: 11, dtype: int64
# 47th-Dan Ryan 2015 11 4    88552
# Name: 11, dtype: int64
# 47th-Dan Ryan 2016 11 4    86238
# Name: 11, dtype: int64
# 47th-Dan Ryan 2017 11 4    77945
# Name: 11, dtype: int64
# 47th-Dan Ryan 2018 11 4    0
# Name: 11, dtype: int64
# 47th-Dan Ryan 2019 11 4    70697
# Name: 11, dtype: int64
# 47th-Dan Ryan 2013 12 4    0
# Name: 12, dtype: int64
# 47th-Dan Ryan 2014 12 4    91062
# Name: 12, dtype: int64
# 47th-Dan Ryan 2015 12 4    88329
# Name: 12, dtype: int64
# 47th-Dan Ryan 2016 12 4    76412
# Name: 12, dtype: int64
# 47th-Dan Ryan 2017 12 4    72682
# Name: 12, dtype: int64
# 47th-Dan Ryan 2018 12 4    0
# Name: 12, dtype: int64
# 47th-Dan Ryan 2019 12 4    68803
# Name: 12, dtype: int64
# 47th-South Elevated 2013 1 5    33272
# Name: 1, dtype: int64
# 47th-South Elevated 2014 1 5    32286
# Name: 1, dtype: int64
# 47th-South Elevated 2015 1 5    30718
# Name: 1, dtype: int64
# 47th-South Elevated 2016 1 5    32884
# Name: 1, dtype: int64
# 47th-South Elevated 2017 1 5    28194
# Name: 1, dtype: int64
# 47th-South Elevated 2018 1 5    27766
# Name: 1, dtype: int64
# 47th-South Elevated 2019 1 5    23441
# Name: 1, dtype: int64
# 47th-South Elevated 2013 2 5    32626
# Name: 2, dtype: int64
# 47th-South Elevated 2014 2 5    34938
# Name: 2, dtype: int64
# 47th-South Elevated 2015 2 5    30284
# Name: 2, dtype: int64
# 47th-South Elevated 2016 2 5    32955
# Name: 2, dtype: int64
# 47th-South Elevated 2017 2 5    28201
# Name: 2, dtype: int64
# 47th-South Elevated 2018 2 5    26607
# Name: 2, dtype: int64
# 47th-South Elevated 2019 2 5    23494
# Name: 2, dtype: int64
# 47th-South Elevated 2013 3 5    33861
# Name: 3, dtype: int64
# 47th-South Elevated 2014 3 5    39301
# Name: 3, dtype: int64
# 47th-South Elevated 2015 3 5    35545
# Name: 3, dtype: int64
# 47th-South Elevated 2016 3 5    35208
# Name: 3, dtype: int64
# 47th-South Elevated 2017 3 5    31221
# Name: 3, dtype: int64
# 47th-South Elevated 2018 3 5    29733
# Name: 3, dtype: int64
# 47th-South Elevated 2019 3 5    25741
# Name: 3, dtype: int64
# 47th-South Elevated 2013 4 5    34916
# Name: 4, dtype: int64
# 47th-South Elevated 2014 4 5    38057
# Name: 4, dtype: int64
# 47th-South Elevated 2015 4 5    35953
# Name: 4, dtype: int64
# 47th-South Elevated 2016 4 5    32186
# Name: 4, dtype: int64
# 47th-South Elevated 2017 4 5    29294
# Name: 4, dtype: int64
# 47th-South Elevated 2018 4 5    28092
# Name: 4, dtype: int64
# 47th-South Elevated 2019 4 5    26132
# Name: 4, dtype: int64
# 47th-South Elevated 2013 5 5    45211
# Name: 5, dtype: int64
# 47th-South Elevated 2014 5 5    39893
# Name: 5, dtype: int64
# 47th-South Elevated 2015 5 5    36446
# Name: 5, dtype: int64
# 47th-South Elevated 2016 5 5    33602
# Name: 5, dtype: int64
# 47th-South Elevated 2017 5 5    31871
# Name: 5, dtype: int64
# 47th-South Elevated 2018 5 5    30393
# Name: 5, dtype: int64
# 47th-South Elevated 2019 5 5    27646
# Name: 5, dtype: int64
# 47th-South Elevated 2013 6 5    57389
# Name: 6, dtype: int64
# 47th-South Elevated 2014 6 5    39232
# Name: 6, dtype: int64
# 47th-South Elevated 2015 6 5    37866
# Name: 6, dtype: int64
# 47th-South Elevated 2016 6 5    33118
# Name: 6, dtype: int64
# 47th-South Elevated 2017 6 5    33021
# Name: 6, dtype: int64
# 47th-South Elevated 2018 6 5    28650
# Name: 6, dtype: int64
# 47th-South Elevated 2019 6 5    27124
# Name: 6, dtype: int64
# 47th-South Elevated 2013 7 5    63177
# Name: 7, dtype: int64
# 47th-South Elevated 2014 7 5    42662
# Name: 7, dtype: int64
# 47th-South Elevated 2015 7 5    41207
# Name: 7, dtype: int64
# 47th-South Elevated 2016 7 5    33495
# Name: 7, dtype: int64
# 47th-South Elevated 2017 7 5    32478
# Name: 7, dtype: int64
# 47th-South Elevated 2018 7 5    30961
# Name: 7, dtype: int64
# 47th-South Elevated 2019 7 5    30072
# Name: 7, dtype: int64
# 47th-South Elevated 2013 8 5    66334
# Name: 8, dtype: int64
# 47th-South Elevated 2014 8 5    43651
# Name: 8, dtype: int64
# 47th-South Elevated 2015 8 5    40777
# Name: 8, dtype: int64
# 47th-South Elevated 2016 8 5    34235
# Name: 8, dtype: int64
# 47th-South Elevated 2017 8 5    34024
# Name: 8, dtype: int64
# 47th-South Elevated 2018 8 5    0
# Name: 8, dtype: int64
# 47th-South Elevated 2019 8 5    30131
# Name: 8, dtype: int64
# 47th-South Elevated 2013 9 5    64135
# Name: 9, dtype: int64
# 47th-South Elevated 2014 9 5    42126
# Name: 9, dtype: int64
# 47th-South Elevated 2015 9 5    39712
# Name: 9, dtype: int64
# 47th-South Elevated 2016 9 5    33130
# Name: 9, dtype: int64
# 47th-South Elevated 2017 9 5    32697
# Name: 9, dtype: int64
# 47th-South Elevated 2018 9 5    0
# Name: 9, dtype: int64
# 47th-South Elevated 2019 9 5    27361
# Name: 9, dtype: int64
# 47th-South Elevated 2013 10 5    60841
# Name: 10, dtype: int64
# 47th-South Elevated 2014 10 5    42653
# Name: 10, dtype: int64
# 47th-South Elevated 2015 10 5    41695
# Name: 10, dtype: int64
# 47th-South Elevated 2016 10 5    33261
# Name: 10, dtype: int64
# 47th-South Elevated 2017 10 5    33464
# Name: 10, dtype: int64
# 47th-South Elevated 2018 10 5    0
# Name: 10, dtype: int64
# 47th-South Elevated 2019 10 5    28419
# Name: 10, dtype: int64
# 47th-South Elevated 2013 11 5    38744
# Name: 11, dtype: int64
# 47th-South Elevated 2014 11 5    32179
# Name: 11, dtype: int64
# 47th-South Elevated 2015 11 5    36338
# Name: 11, dtype: int64
# 47th-South Elevated 2016 11 5    31454
# Name: 11, dtype: int64
# 47th-South Elevated 2017 11 5    30940
# Name: 11, dtype: int64
# 47th-South Elevated 2018 11 5    0
# Name: 11, dtype: int64
# 47th-South Elevated 2019 11 5    23046
# Name: 11, dtype: int64
# 47th-South Elevated 2013 12 5    35661
# Name: 12, dtype: int64
# 47th-South Elevated 2014 12 5    32384
# Name: 12, dtype: int64
# 47th-South Elevated 2015 12 5    36263
# Name: 12, dtype: int64
# 47th-South Elevated 2016 12 5    28651
# Name: 12, dtype: int64
# 47th-South Elevated 2017 12 5    28513
# Name: 12, dtype: int64
# 47th-South Elevated 2018 12 5    0
# Name: 12, dtype: int64
# 47th-South Elevated 2019 12 5    22370
# Name: 12, dtype: int64
# 51st 2013 1 6    29527
# Name: 1, dtype: int64
# 51st 2014 1 6    27757
# Name: 1, dtype: int64
# 51st 2015 1 6    25178
# Name: 1, dtype: int64
# 51st 2016 1 6    26069
# Name: 1, dtype: int64
# 51st 2017 1 6    22904
# Name: 1, dtype: int64
# 51st 2018 1 6    23280
# Name: 1, dtype: int64
# 51st 2019 1 6    22410
# Name: 1, dtype: int64
# 51st 2013 2 6    27240
# Name: 2, dtype: int64
# 51st 2014 2 6    28569
# Name: 2, dtype: int64
# 51st 2015 2 6    24282
# Name: 2, dtype: int64
# 51st 2016 2 6    25989
# Name: 2, dtype: int64
# 51st 2017 2 6    22720
# Name: 2, dtype: int64
# 51st 2018 2 6    21824
# Name: 2, dtype: int64
# 51st 2019 2 6    21508
# Name: 2, dtype: int64
# 51st 2013 3 6    28830
# Name: 3, dtype: int64
# 51st 2014 3 6    31834
# Name: 3, dtype: int64
# 51st 2015 3 6    29557
# Name: 3, dtype: int64
# 51st 2016 3 6    28700
# Name: 3, dtype: int64
# 51st 2017 3 6    25382
# Name: 3, dtype: int64
# 51st 2018 3 6    25350
# Name: 3, dtype: int64
# 51st 2019 3 6    23750
# Name: 3, dtype: int64
# 51st 2013 4 6    30665
# Name: 4, dtype: int64
# 51st 2014 4 6    30727
# Name: 4, dtype: int64
# 51st 2015 4 6    30313
# Name: 4, dtype: int64
# 51st 2016 4 6    27177
# Name: 4, dtype: int64
# 51st 2017 4 6    23231
# Name: 4, dtype: int64
# 51st 2018 4 6    24012
# Name: 4, dtype: int64
# 51st 2019 4 6    23503
# Name: 4, dtype: int64
# 51st 2013 5 6    36702
# Name: 5, dtype: int64
# 51st 2014 5 6    32363
# Name: 5, dtype: int64
# 51st 2015 5 6    31134
# Name: 5, dtype: int64
# 51st 2016 5 6    28292
# Name: 5, dtype: int64
# 51st 2017 5 6    25231
# Name: 5, dtype: int64
# 51st 2018 5 6    26047
# Name: 5, dtype: int64
# 51st 2019 5 6    24736
# Name: 5, dtype: int64
# 51st 2013 6 6    42981
# Name: 6, dtype: int64
# 51st 2014 6 6    29756
# Name: 6, dtype: int64
# 51st 2015 6 6    31940
# Name: 6, dtype: int64
# 51st 2016 6 6    29061
# Name: 6, dtype: int64
# 51st 2017 6 6    25721
# Name: 6, dtype: int64
# 51st 2018 6 6    25798
# Name: 6, dtype: int64
# 51st 2019 6 6    23750
# Name: 6, dtype: int64
# 51st 2013 7 6    46131
# Name: 7, dtype: int64
# 51st 2014 7 6    29950
# Name: 7, dtype: int64
# 51st 2015 7 6    33798
# Name: 7, dtype: int64
# 51st 2016 7 6    29238
# Name: 7, dtype: int64
# 51st 2017 7 6    25877
# Name: 7, dtype: int64
# 51st 2018 7 6    26980
# Name: 7, dtype: int64
# 51st 2019 7 6    26601
# Name: 7, dtype: int64
# 51st 2013 8 6    47999
# Name: 8, dtype: int64
# 51st 2014 8 6    31403
# Name: 8, dtype: int64
# 51st 2015 8 6    32482
# Name: 8, dtype: int64
# 51st 2016 8 6    28476
# Name: 8, dtype: int64
# 51st 2017 8 6    28586
# Name: 8, dtype: int64
# 51st 2018 8 6    0
# Name: 8, dtype: int64
# 51st 2019 8 6    26611
# Name: 8, dtype: int64
# 51st 2013 9 6    48155
# Name: 9, dtype: int64
# 51st 2014 9 6    31398
# Name: 9, dtype: int64
# 51st 2015 9 6    32884
# Name: 9, dtype: int64
# 51st 2016 9 6    28087
# Name: 9, dtype: int64
# 51st 2017 9 6    27610
# Name: 9, dtype: int64
# 51st 2018 9 6    0
# Name: 9, dtype: int64
# 51st 2019 9 6    25086
# Name: 9, dtype: int64
# 51st 2013 10 6    46777
# Name: 10, dtype: int64
# 51st 2014 10 6    33630
# Name: 10, dtype: int64
# 51st 2015 10 6    33899
# Name: 10, dtype: int64
# 51st 2016 10 6    28739
# Name: 10, dtype: int64
# 51st 2017 10 6    28589
# Name: 10, dtype: int64
# 51st 2018 10 6    0
# Name: 10, dtype: int64
# 51st 2019 10 6    25956
# Name: 10, dtype: int64
# 51st 2013 11 6    32823
# Name: 11, dtype: int64
# 51st 2014 11 6    27283
# Name: 11, dtype: int64
# 51st 2015 11 6    28474
# Name: 11, dtype: int64
# 51st 2016 11 6    25983
# Name: 11, dtype: int64
# 51st 2017 11 6    25305
# Name: 11, dtype: int64
# 51st 2018 11 6    0
# Name: 11, dtype: int64
# 51st 2019 11 6    22072
# Name: 11, dtype: int64
# 51st 2013 12 6    29619
# Name: 12, dtype: int64
# 51st 2014 12 6    27639
# Name: 12, dtype: int64
# 51st 2015 12 6    28848
# Name: 12, dtype: int64
# 51st 2016 12 6    23564
# Name: 12, dtype: int64
# 51st 2017 12 6    23203
# Name: 12, dtype: int64
# 51st 2018 12 6    0
# Name: 12, dtype: int64
# 51st 2019 12 6    22124
# Name: 12, dtype: int64
# 54th/Cermak 2013 1 7    50230
# Name: 1, dtype: int64
# 54th/Cermak 2014 1 7    47726
# Name: 1, dtype: int64
# 54th/Cermak 2015 1 7    52284
# Name: 1, dtype: int64
# 54th/Cermak 2016 1 7    51595
# Name: 1, dtype: int64
# 54th/Cermak 2017 1 7    50832
# Name: 1, dtype: int64
# 54th/Cermak 2018 1 7    48504
# Name: 1, dtype: int64
# 54th/Cermak 2019 1 7    45524
# Name: 1, dtype: int64
# 54th/Cermak 2013 2 7    46750
# Name: 2, dtype: int64
# 54th/Cermak 2014 2 7    48840
# Name: 2, dtype: int64
# 54th/Cermak 2015 2 7    49342
# Name: 2, dtype: int64
# 54th/Cermak 2016 2 7    51860
# Name: 2, dtype: int64
# 54th/Cermak 2017 2 7    50115
# Name: 2, dtype: int64
# 54th/Cermak 2018 2 7    46293
# Name: 2, dtype: int64
# 54th/Cermak 2019 2 7    46026
# Name: 2, dtype: int64
# 54th/Cermak 2013 3 7    51684
# Name: 3, dtype: int64
# 54th/Cermak 2014 3 7    55074
# Name: 3, dtype: int64
# 54th/Cermak 2015 3 7    59152
# Name: 3, dtype: int64
# 54th/Cermak 2016 3 7    55729
# Name: 3, dtype: int64
# 54th/Cermak 2017 3 7    55896
# Name: 3, dtype: int64
# 54th/Cermak 2018 3 7    52063
# Name: 3, dtype: int64
# 54th/Cermak 2019 3 7    51518
# Name: 3, dtype: int64
# 54th/Cermak 2013 4 7    56295
# Name: 4, dtype: int64
# 54th/Cermak 2014 4 7    58036
# Name: 4, dtype: int64
# 54th/Cermak 2015 4 7    60244
# Name: 4, dtype: int64
# 54th/Cermak 2016 4 7    53049
# Name: 4, dtype: int64
# 54th/Cermak 2017 4 7    53320
# Name: 4, dtype: int64
# 54th/Cermak 2018 4 7    50799
# Name: 4, dtype: int64
# 54th/Cermak 2019 4 7    53825
# Name: 4, dtype: int64
# 54th/Cermak 2013 5 7    56436
# Name: 5, dtype: int64
# 54th/Cermak 2014 5 7    57613
# Name: 5, dtype: int64
# 54th/Cermak 2015 5 7    59908
# Name: 5, dtype: int64
# 54th/Cermak 2016 5 7    56123
# Name: 5, dtype: int64
# 54th/Cermak 2017 5 7    58186
# Name: 5, dtype: int64
# 54th/Cermak 2018 5 7    57099
# Name: 5, dtype: int64
# 54th/Cermak 2019 5 7    57002
# Name: 5, dtype: int64
# 54th/Cermak 2013 6 7    57915
# Name: 6, dtype: int64
# 54th/Cermak 2014 6 7    58966
# Name: 6, dtype: int64
# 54th/Cermak 2015 6 7    64139
# Name: 6, dtype: int64
# 54th/Cermak 2016 6 7    59727
# Name: 6, dtype: int64
# 54th/Cermak 2017 6 7    61094
# Name: 6, dtype: int64
# 54th/Cermak 2018 6 7    57562
# Name: 6, dtype: int64
# 54th/Cermak 2019 6 7    56707
# Name: 6, dtype: int64
# 54th/Cermak 2013 7 7    62100
# Name: 7, dtype: int64
# 54th/Cermak 2014 7 7    64673
# Name: 7, dtype: int64
# 54th/Cermak 2015 7 7    67887
# Name: 7, dtype: int64
# 54th/Cermak 2016 7 7    59602
# Name: 7, dtype: int64
# 54th/Cermak 2017 7 7    58762
# Name: 7, dtype: int64
# 54th/Cermak 2018 7 7    58204
# Name: 7, dtype: int64
# 54th/Cermak 2019 7 7    58310
# Name: 7, dtype: int64
# 54th/Cermak 2013 8 7    59531
# Name: 8, dtype: int64
# 54th/Cermak 2014 8 7    63227
# Name: 8, dtype: int64
# 54th/Cermak 2015 8 7    63769
# Name: 8, dtype: int64
# 54th/Cermak 2016 8 7    59734
# Name: 8, dtype: int64
# 54th/Cermak 2017 8 7    62818
# Name: 8, dtype: int64
# 54th/Cermak 2018 8 7    0
# Name: 8, dtype: int64
# 54th/Cermak 2019 8 7    58853
# Name: 8, dtype: int64
# 54th/Cermak 2013 9 7    57630
# Name: 9, dtype: int64
# 54th/Cermak 2014 9 7    63368
# Name: 9, dtype: int64
# 54th/Cermak 2015 9 7    65723
# Name: 9, dtype: int64
# 54th/Cermak 2016 9 7    59789
# Name: 9, dtype: int64
# 54th/Cermak 2017 9 7    59916
# Name: 9, dtype: int64
# 54th/Cermak 2018 9 7    0
# Name: 9, dtype: int64
# 54th/Cermak 2019 9 7    57971
# Name: 9, dtype: int64
# 54th/Cermak 2013 10 7    61643
# Name: 10, dtype: int64
# 54th/Cermak 2014 10 7    65575
# Name: 10, dtype: int64
# 54th/Cermak 2015 10 7    66726
# Name: 10, dtype: int64
# 54th/Cermak 2016 10 7    59784
# Name: 10, dtype: int64
# 54th/Cermak 2017 10 7    60462
# Name: 10, dtype: int64
# 54th/Cermak 2018 10 7    0
# Name: 10, dtype: int64
# 54th/Cermak 2019 10 7    60191
# Name: 10, dtype: int64
# 54th/Cermak 2013 11 7    53595
# Name: 11, dtype: int64
# 54th/Cermak 2014 11 7    54277
# Name: 11, dtype: int64
# 54th/Cermak 2015 11 7    59271
# Name: 11, dtype: int64
# 54th/Cermak 2016 11 7    59135
# Name: 11, dtype: int64
# 54th/Cermak 2017 11 7    55634
# Name: 11, dtype: int64
# 54th/Cermak 2018 11 7    0
# Name: 11, dtype: int64
# 54th/Cermak 2019 11 7    52434
# Name: 11, dtype: int64
# 54th/Cermak 2013 12 7    50239
# Name: 12, dtype: int64
# 54th/Cermak 2014 12 7    56526
# Name: 12, dtype: int64
# 54th/Cermak 2015 12 7    58120
# Name: 12, dtype: int64
# 54th/Cermak 2016 12 7    51339
# Name: 12, dtype: int64
# 54th/Cermak 2017 12 7    50229
# Name: 12, dtype: int64
# 54th/Cermak 2018 12 7    0
# Name: 12, dtype: int64
# 54th/Cermak 2019 12 7    49205
# Name: 12, dtype: int64
# 63rd-Dan Ryan 2013 1 8    85289
# Name: 1, dtype: int64
# 63rd-Dan Ryan 2014 1 8    77812
# Name: 1, dtype: int64
# 63rd-Dan Ryan 2015 1 8    88930
# Name: 1, dtype: int64
# 63rd-Dan Ryan 2016 1 8    77368
# Name: 1, dtype: int64
# 63rd-Dan Ryan 2017 1 8    77537
# Name: 1, dtype: int64
# 63rd-Dan Ryan 2018 1 8    73332
# Name: 1, dtype: int64
# 63rd-Dan Ryan 2019 1 8    70664
# Name: 1, dtype: int64
# 63rd-Dan Ryan 2013 2 8    78791
# Name: 2, dtype: int64
# 63rd-Dan Ryan 2014 2 8    82197
# Name: 2, dtype: int64
# 63rd-Dan Ryan 2015 2 8    75786
# Name: 2, dtype: int64
# 63rd-Dan Ryan 2016 2 8    82067
# Name: 2, dtype: int64
# 63rd-Dan Ryan 2017 2 8    77882
# Name: 2, dtype: int64
# 63rd-Dan Ryan 2018 2 8    70754
# Name: 2, dtype: int64
# 63rd-Dan Ryan 2019 2 8    70601
# Name: 2, dtype: int64
# 63rd-Dan Ryan 2013 3 8    84509
# Name: 3, dtype: int64
# 63rd-Dan Ryan 2014 3 8    93573
# Name: 3, dtype: int64
# 63rd-Dan Ryan 2015 3 8    88023
# Name: 3, dtype: int64
# 63rd-Dan Ryan 2016 3 8    91102
# Name: 3, dtype: int64
# 63rd-Dan Ryan 2017 3 8    84404
# Name: 3, dtype: int64
# 63rd-Dan Ryan 2018 3 8    79511
# Name: 3, dtype: int64
# 63rd-Dan Ryan 2019 3 8    77570
# Name: 3, dtype: int64
# 63rd-Dan Ryan 2013 4 8    83472
# Name: 4, dtype: int64
# 63rd-Dan Ryan 2014 4 8    90262
# Name: 4, dtype: int64
# 63rd-Dan Ryan 2015 4 8    84564
# Name: 4, dtype: int64
# 63rd-Dan Ryan 2016 4 8    85833
# Name: 4, dtype: int64
# 63rd-Dan Ryan 2017 4 8    76543
# Name: 4, dtype: int64
# 63rd-Dan Ryan 2018 4 8    77803
# Name: 4, dtype: int64
# 63rd-Dan Ryan 2019 4 8    76517
# Name: 4, dtype: int64
# 63rd-Dan Ryan 2013 5 8    50104
# Name: 5, dtype: int64
# 63rd-Dan Ryan 2014 5 8    95897
# Name: 5, dtype: int64
# 63rd-Dan Ryan 2015 5 8    85861
# Name: 5, dtype: int64
# 63rd-Dan Ryan 2016 5 8    92610
# Name: 5, dtype: int64
# 63rd-Dan Ryan 2017 5 8    85779
# Name: 5, dtype: int64
# 63rd-Dan Ryan 2018 5 8    86265
# Name: 5, dtype: int64
# 63rd-Dan Ryan 2019 5 8    83109
# Name: 5, dtype: int64
# 63rd-Dan Ryan 2013 6 8    0
# Name: 6, dtype: int64
# 63rd-Dan Ryan 2014 6 8    89512
# Name: 6, dtype: int64
# 63rd-Dan Ryan 2015 6 8    83137
# Name: 6, dtype: int64
# 63rd-Dan Ryan 2016 6 8    90294
# Name: 6, dtype: int64
# 63rd-Dan Ryan 2017 6 8    83017
# Name: 6, dtype: int64
# 63rd-Dan Ryan 2018 6 8    81407
# Name: 6, dtype: int64
# 63rd-Dan Ryan 2019 6 8    78781
# Name: 6, dtype: int64
# 63rd-Dan Ryan 2013 7 8    0
# Name: 7, dtype: int64
# 63rd-Dan Ryan 2014 7 8    94195
# Name: 7, dtype: int64
# 63rd-Dan Ryan 2015 7 8    84845
# Name: 7, dtype: int64
# 63rd-Dan Ryan 2016 7 8    85942
# Name: 7, dtype: int64
# 63rd-Dan Ryan 2017 7 8    79775
# Name: 7, dtype: int64
# 63rd-Dan Ryan 2018 7 8    81686
# Name: 7, dtype: int64
# 63rd-Dan Ryan 2019 7 8    79577
# Name: 7, dtype: int64
# 63rd-Dan Ryan 2013 8 8    0
# Name: 8, dtype: int64
# 63rd-Dan Ryan 2014 8 8    95246
# Name: 8, dtype: int64
# 63rd-Dan Ryan 2015 8 8    85321
# Name: 8, dtype: int64
# 63rd-Dan Ryan 2016 8 8    86898
# Name: 8, dtype: int64
# 63rd-Dan Ryan 2017 8 8    83425
# Name: 8, dtype: int64
# 63rd-Dan Ryan 2018 8 8    0
# Name: 8, dtype: int64
# 63rd-Dan Ryan 2019 8 8    80681
# Name: 8, dtype: int64
# 63rd-Dan Ryan 2013 9 8    31358
# Name: 9, dtype: int64
# 63rd-Dan Ryan 2014 9 8    107126
# Name: 9, dtype: int64
# 63rd-Dan Ryan 2015 9 8    93610
# Name: 9, dtype: int64
# 63rd-Dan Ryan 2016 9 8    94919
# Name: 9, dtype: int64
# 63rd-Dan Ryan 2017 9 8    87053
# Name: 9, dtype: int64
# 63rd-Dan Ryan 2018 9 8    0
# Name: 9, dtype: int64
# 63rd-Dan Ryan 2019 9 8    83198
# Name: 9, dtype: int64
# 63rd-Dan Ryan 2013 10 8    82649
# Name: 10, dtype: int64
# 63rd-Dan Ryan 2014 10 8    112922
# Name: 10, dtype: int64
# 63rd-Dan Ryan 2015 10 8    97969
# Name: 10, dtype: int64
# 63rd-Dan Ryan 2016 10 8    94946
# Name: 10, dtype: int64
# 63rd-Dan Ryan 2017 10 8    87875
# Name: 10, dtype: int64
# 63rd-Dan Ryan 2018 10 8    0
# Name: 10, dtype: int64
# 63rd-Dan Ryan 2019 10 8    85403
# Name: 10, dtype: int64
# 63rd-Dan Ryan 2013 11 8    80318
# Name: 11, dtype: int64
# 63rd-Dan Ryan 2014 11 8    93411
# Name: 11, dtype: int64
# 63rd-Dan Ryan 2015 11 8    83921
# Name: 11, dtype: int64
# 63rd-Dan Ryan 2016 11 8    87449
# Name: 11, dtype: int64
# 63rd-Dan Ryan 2017 11 8    80951
# Name: 11, dtype: int64
# 63rd-Dan Ryan 2018 11 8    0
# Name: 11, dtype: int64
# 63rd-Dan Ryan 2019 11 8    76552
# Name: 11, dtype: int64
# 63rd-Dan Ryan 2013 12 8    0
# Name: 12, dtype: int64
# 63rd-Dan Ryan 2014 12 8    95440
# Name: 12, dtype: int64
# 63rd-Dan Ryan 2015 12 8    83063
# Name: 12, dtype: int64
# 63rd-Dan Ryan 2016 12 8    78192
# Name: 12, dtype: int64
# 63rd-Dan Ryan 2017 12 8    75113
# Name: 12, dtype: int64
# 63rd-Dan Ryan 2018 12 8    0
# Name: 12, dtype: int64
# 63rd-Dan Ryan 2019 12 8    75077
# Name: 12, dtype: int64
# 69th 2013 1 9    141035
# Name: 1, dtype: int64
# 69th 2014 1 9    120179
# Name: 1, dtype: int64
# 69th 2015 1 9    143029
# Name: 1, dtype: int64
# 69th 2016 1 9    142458
# Name: 1, dtype: int64
# 69th 2017 1 9    133445
# Name: 1, dtype: int64
# 69th 2018 1 9    122969
# Name: 1, dtype: int64
# 69th 2019 1 9    111784
# Name: 1, dtype: int64
# 69th 2013 2 9    129147
# Name: 2, dtype: int64
# 69th 2014 2 9    127862
# Name: 2, dtype: int64
# 69th 2015 2 9    130589
# Name: 2, dtype: int64
# 69th 2016 2 9    140608
# Name: 2, dtype: int64
# 69th 2017 2 9    130232
# Name: 2, dtype: int64
# 69th 2018 2 9    114109
# Name: 2, dtype: int64
# 69th 2019 2 9    109073
# Name: 2, dtype: int64
# 69th 2013 3 9    139380
# Name: 3, dtype: int64
# 69th 2014 3 9    145593
# Name: 3, dtype: int64
# 69th 2015 3 9    155146
# Name: 3, dtype: int64
# 69th 2016 3 9    151438
# Name: 3, dtype: int64
# 69th 2017 3 9    139577
# Name: 3, dtype: int64
# 69th 2018 3 9    128843
# Name: 3, dtype: int64
# 69th 2019 3 9    119037
# Name: 3, dtype: int64
# 69th 2013 4 9    139214
# Name: 4, dtype: int64
# 69th 2014 4 9    145563
# Name: 4, dtype: int64
# 69th 2015 4 9    151025
# Name: 4, dtype: int64
# 69th 2016 4 9    145115
# Name: 4, dtype: int64
# 69th 2017 4 9    128860
# Name: 4, dtype: int64
# 69th 2018 4 9    125430
# Name: 4, dtype: int64
# 69th 2019 4 9    116649
# Name: 4, dtype: int64
# 69th 2013 5 9    82930
# Name: 5, dtype: int64
# 69th 2014 5 9    154284
# Name: 5, dtype: int64
# 69th 2015 5 9    158489
# Name: 5, dtype: int64
# 69th 2016 5 9    152053
# Name: 5, dtype: int64
# 69th 2017 5 9    142966
# Name: 5, dtype: int64
# 69th 2018 5 9    138577
# Name: 5, dtype: int64
# 69th 2019 5 9    126835
# Name: 5, dtype: int64
# 69th 2013 6 9    0
# Name: 6, dtype: int64
# 69th 2014 6 9    146313
# Name: 6, dtype: int64
# 69th 2015 6 9    157767
# Name: 6, dtype: int64
# 69th 2016 6 9    151638
# Name: 6, dtype: int64
# 69th 2017 6 9    142850
# Name: 6, dtype: int64
# 69th 2018 6 9    132902
# Name: 6, dtype: int64
# 69th 2019 6 9    117486
# Name: 6, dtype: int64
# 69th 2013 7 9    0
# Name: 7, dtype: int64
# 69th 2014 7 9    154043
# Name: 7, dtype: int64
# 69th 2015 7 9    165695
# Name: 7, dtype: int64
# 69th 2016 7 9    151395
# Name: 7, dtype: int64
# 69th 2017 7 9    140833
# Name: 7, dtype: int64
# 69th 2018 7 9    135383
# Name: 7, dtype: int64
# 69th 2019 7 9    127780
# Name: 7, dtype: int64
# 69th 2013 8 9    0
# Name: 8, dtype: int64
# 69th 2014 8 9    155716
# Name: 8, dtype: int64
# 69th 2015 8 9    158514
# Name: 8, dtype: int64
# 69th 2016 8 9    149865
# Name: 8, dtype: int64
# 69th 2017 8 9    146511
# Name: 8, dtype: int64
# 69th 2018 8 9    0
# Name: 8, dtype: int64
# 69th 2019 8 9    125537
# Name: 8, dtype: int64
# 69th 2013 9 9    49826
# Name: 9, dtype: int64
# 69th 2014 9 9    166263
# Name: 9, dtype: int64
# 69th 2015 9 9    163691
# Name: 9, dtype: int64
# 69th 2016 9 9    151756
# Name: 9, dtype: int64
# 69th 2017 9 9    144708
# Name: 9, dtype: int64
# 69th 2018 9 9    0
# Name: 9, dtype: int64
# 69th 2019 9 9    121308
# Name: 9, dtype: int64
# 69th 2013 10 9    125473
# Name: 10, dtype: int64
# 69th 2014 10 9    176380
# Name: 10, dtype: int64
# 69th 2015 10 9    176152
# Name: 10, dtype: int64
# 69th 2016 10 9    158686
# Name: 10, dtype: int64
# 69th 2017 10 9    149748
# Name: 10, dtype: int64
# 69th 2018 10 9    0
# Name: 10, dtype: int64
# 69th 2019 10 9    127325
# Name: 10, dtype: int64
# 69th 2013 11 9    125655
# Name: 11, dtype: int64
# 69th 2014 11 9    151812
# Name: 11, dtype: int64
# 69th 2015 11 9    156143
# Name: 11, dtype: int64
# 69th 2016 11 9    149318
# Name: 11, dtype: int64
# 69th 2017 11 9    136751
# Name: 11, dtype: int64
# 69th 2018 11 9    0
# Name: 11, dtype: int64
# 69th 2019 11 9    111346
# Name: 11, dtype: int64
# 69th 2013 12 9    0
# Name: 12, dtype: int64
# 69th 2014 12 9    155993
# Name: 12, dtype: int64
# 69th 2015 12 9    154216
# Name: 12, dtype: int64
# 69th 2016 12 9    135771
# Name: 12, dtype: int64
# 69th 2017 12 9    128837
# Name: 12, dtype: int64
# 69th 2018 12 9    0
# Name: 12, dtype: int64
# 69th 2019 12 9    109765
# Name: 12, dtype: int64
# 79th 2013 1 10    184402
# Name: 1, dtype: int64
# 79th 2014 1 10    166945
# Name: 1, dtype: int64
# 79th 2015 1 10    190847
# Name: 1, dtype: int64
# 79th 2016 1 10    191070
# Name: 1, dtype: int64
# 79th 2017 1 10    177679
# Name: 1, dtype: int64
# 79th 2018 1 10    166892
# Name: 1, dtype: int64
# 79th 2019 1 10    148318
# Name: 1, dtype: int64
# 79th 2013 2 10    171824
# Name: 2, dtype: int64
# 79th 2014 2 10    174744
# Name: 2, dtype: int64
# 79th 2015 2 10    176634
# Name: 2, dtype: int64
# 79th 2016 2 10    187756
# Name: 2, dtype: int64
# 79th 2017 2 10    172020
# Name: 2, dtype: int64
# 79th 2018 2 10    157092
# Name: 2, dtype: int64
# 79th 2019 2 10    148030
# Name: 2, dtype: int64
# 79th 2013 3 10    185155
# Name: 3, dtype: int64
# 79th 2014 3 10    198550
# Name: 3, dtype: int64
# 79th 2015 3 10    207094
# Name: 3, dtype: int64
# 79th 2016 3 10    200891
# Name: 3, dtype: int64
# 79th 2017 3 10    187752
# Name: 3, dtype: int64
# 79th 2018 3 10    175061
# Name: 3, dtype: int64
# 79th 2019 3 10    161092
# Name: 3, dtype: int64
# 79th 2013 4 10    183400
# Name: 4, dtype: int64
# 79th 2014 4 10    195840
# Name: 4, dtype: int64
# 79th 2015 4 10    204192
# Name: 4, dtype: int64
# 79th 2016 4 10    189557
# Name: 4, dtype: int64
# 79th 2017 4 10    173731
# Name: 4, dtype: int64
# 79th 2018 4 10    170629
# Name: 4, dtype: int64
# 79th 2019 4 10    159341
# Name: 4, dtype: int64
# 79th 2013 5 10    109837
# Name: 5, dtype: int64
# 79th 2014 5 10    205361
# Name: 5, dtype: int64
# 79th 2015 5 10    212971
# Name: 5, dtype: int64
# 79th 2016 5 10    200772
# Name: 5, dtype: int64
# 79th 2017 5 10    190900
# Name: 5, dtype: int64
# 79th 2018 5 10    186548
# Name: 5, dtype: int64
# 79th 2019 5 10    174825
# Name: 5, dtype: int64
# 79th 2013 6 10    0
# Name: 6, dtype: int64
# 79th 2014 6 10    197313
# Name: 6, dtype: int64
# 79th 2015 6 10    213886
# Name: 6, dtype: int64
# 79th 2016 6 10    201117
# Name: 6, dtype: int64
# 79th 2017 6 10    190728
# Name: 6, dtype: int64
# 79th 2018 6 10    180400
# Name: 6, dtype: int64
# 79th 2019 6 10    167957
# Name: 6, dtype: int64
# 79th 2013 7 10    0
# Name: 7, dtype: int64
# 79th 2014 7 10    206910
# Name: 7, dtype: int64
# 79th 2015 7 10    223282
# Name: 7, dtype: int64
# 79th 2016 7 10    198741
# Name: 7, dtype: int64
# 79th 2017 7 10    187542
# Name: 7, dtype: int64
# 79th 2018 7 10    184925
# Name: 7, dtype: int64
# 79th 2019 7 10    177018
# Name: 7, dtype: int64
# 79th 2013 8 10    0
# Name: 8, dtype: int64
# 79th 2014 8 10    207727
# Name: 8, dtype: int64
# 79th 2015 8 10    215254
# Name: 8, dtype: int64
# 79th 2016 8 10    200006
# Name: 8, dtype: int64
# 79th 2017 8 10    191966
# Name: 8, dtype: int64
# 79th 2018 8 10    0
# Name: 8, dtype: int64
# 79th 2019 8 10    175973
# Name: 8, dtype: int64
# 79th 2013 9 10    67492
# Name: 9, dtype: int64
# 79th 2014 9 10    222370
# Name: 9, dtype: int64
# 79th 2015 9 10    222504
# Name: 9, dtype: int64
# 79th 2016 9 10    199811
# Name: 9, dtype: int64
# 79th 2017 9 10    189039
# Name: 9, dtype: int64
# 79th 2018 9 10    0
# Name: 9, dtype: int64
# 79th 2019 9 10    170637
# Name: 9, dtype: int64
# 79th 2013 10 10    167737
# Name: 10, dtype: int64
# 79th 2014 10 10    234123
# Name: 10, dtype: int64
# 79th 2015 10 10    231365
# Name: 10, dtype: int64
# 79th 2016 10 10    209526
# Name: 10, dtype: int64
# 79th 2017 10 10    196076
# Name: 10, dtype: int64
# 79th 2018 10 10    0
# Name: 10, dtype: int64
# 79th 2019 10 10    177559
# Name: 10, dtype: int64
# 79th 2013 11 10    173690
# Name: 11, dtype: int64
# 79th 2014 11 10    200710
# Name: 11, dtype: int64
# 79th 2015 11 10    203493
# Name: 11, dtype: int64
# 79th 2016 11 10    198387
# Name: 11, dtype: int64
# 79th 2017 11 10    182331
# Name: 11, dtype: int64
# 79th 2018 11 10    0
# Name: 11, dtype: int64
# 79th 2019 11 10    158249
# Name: 11, dtype: int64
# 79th 2013 12 10    0
# Name: 12, dtype: int64
# 79th 2014 12 10    208083
# Name: 12, dtype: int64
# 79th 2015 12 10    206349
# Name: 12, dtype: int64
# 79th 2016 12 10    185562
# Name: 12, dtype: int64
# 79th 2017 12 10    173351
# Name: 12, dtype: int64
# 79th 2018 12 10    0
# Name: 12, dtype: int64
# 79th 2019 12 10    156867
# Name: 12, dtype: int64
# 87th 2013 1 11    114526
# Name: 1, dtype: int64
# 87th 2014 1 11    99271
# Name: 1, dtype: int64
# 87th 2015 1 11    116141
# Name: 1, dtype: int64
# 87th 2016 1 11    109995
# Name: 1, dtype: int64
# 87th 2017 1 11    105298
# Name: 1, dtype: int64
# 87th 2018 1 11    97951
# Name: 1, dtype: int64
# 87th 2019 1 11    89398
# Name: 1, dtype: int64
# 87th 2013 2 11    104661
# Name: 2, dtype: int64
# 87th 2014 2 11    105892
# Name: 2, dtype: int64
# 87th 2015 2 11    107743
# Name: 2, dtype: int64
# 87th 2016 2 11    110297
# Name: 2, dtype: int64
# 87th 2017 2 11    103166
# Name: 2, dtype: int64
# 87th 2018 2 11    94417
# Name: 2, dtype: int64
# 87th 2019 2 11    89051
# Name: 2, dtype: int64
# 87th 2013 3 11    113746
# Name: 3, dtype: int64
# 87th 2014 3 11    120733
# Name: 3, dtype: int64
# 87th 2015 3 11    127366
# Name: 3, dtype: int64
# 87th 2016 3 11    119969
# Name: 3, dtype: int64
# 87th 2017 3 11    111798
# ...
# Thorndale 2016 4 133    84381
# Name: 4, dtype: int64
# Thorndale 2017 4 133    79271
# Name: 4, dtype: int64
# Thorndale 2018 4 133    81350
# Name: 4, dtype: int64
# Thorndale 2019 4 132    76337
# Name: 4, dtype: int64
# Thorndale 2013 5 132    78881
# Name: 5, dtype: int64
# Thorndale 2014 5 132    87198
# Name: 5, dtype: int64
# Thorndale 2015 5 133    87221
# Name: 5, dtype: int64
# Thorndale 2016 5 133    87945
# Name: 5, dtype: int64
# Thorndale 2017 5 133    87640
# Name: 5, dtype: int64
# Thorndale 2018 5 133    85844
# Name: 5, dtype: int64
# Thorndale 2019 5 132    81435
# Name: 5, dtype: int64
# Thorndale 2013 6 132    77113
# Name: 6, dtype: int64
# Thorndale 2014 6 132    80646
# Name: 6, dtype: int64
# Thorndale 2015 6 133    86271
# Name: 6, dtype: int64
# Thorndale 2016 6 133    86226
# Name: 6, dtype: int64
# Thorndale 2017 6 133    84775
# Name: 6, dtype: int64
# Thorndale 2018 6 133    81162
# Name: 6, dtype: int64
# Thorndale 2019 6 132    77671
# Name: 6, dtype: int64
# Thorndale 2013 7 132    76247
# Name: 7, dtype: int64
# Thorndale 2014 7 132    79557
# Name: 7, dtype: int64
# Thorndale 2015 7 133    83073
# Name: 7, dtype: int64
# Thorndale 2016 7 133    79965
# Name: 7, dtype: int64
# Thorndale 2017 7 133    75282
# Name: 7, dtype: int64
# Thorndale 2018 7 133    75722
# Name: 7, dtype: int64
# Thorndale 2019 7 132    81668
# Name: 7, dtype: int64
# Thorndale 2013 8 132    82271
# Name: 8, dtype: int64
# Thorndale 2014 8 132    79131
# Name: 8, dtype: int64
# Thorndale 2015 8 133    82195
# Name: 8, dtype: int64
# Thorndale 2016 8 133    80207
# Name: 8, dtype: int64
# Thorndale 2017 8 133    81272
# Name: 8, dtype: int64
# Thorndale 2018 8 133    0
# Name: 8, dtype: int64
# Thorndale 2019 8 132    79896
# Name: 8, dtype: int64
# Thorndale 2013 9 132    87385
# Name: 9, dtype: int64
# Thorndale 2014 9 132    88033
# Name: 9, dtype: int64
# Thorndale 2015 9 133    89534
# Name: 9, dtype: int64
# Thorndale 2016 9 133    88131
# Name: 9, dtype: int64
# Thorndale 2017 9 133    87204
# Name: 9, dtype: int64
# Thorndale 2018 9 133    0
# Name: 9, dtype: int64
# Thorndale 2019 9 132    85068
# Name: 9, dtype: int64
# Thorndale 2013 10 132    95380
# Name: 10, dtype: int64
# Thorndale 2014 10 132    94739
# Name: 10, dtype: int64
# Thorndale 2015 10 133    96366
# Name: 10, dtype: int64
# Thorndale 2016 10 133    93496
# Name: 10, dtype: int64
# Thorndale 2017 10 133    89869
# Name: 10, dtype: int64
# Thorndale 2018 10 133    0
# Name: 10, dtype: int64
# Thorndale 2019 10 132    81980
# Name: 10, dtype: int64
# Thorndale 2013 11 132    83635
# Name: 11, dtype: int64
# Thorndale 2014 11 132    80016
# Name: 11, dtype: int64
# Thorndale 2015 11 133    82274
# Name: 11, dtype: int64
# Thorndale 2016 11 133    85170
# Name: 11, dtype: int64
# Thorndale 2017 11 133    82388
# Name: 11, dtype: int64
# Thorndale 2018 11 133    0
# Name: 11, dtype: int64
# Thorndale 2019 11 132    74385
# Name: 11, dtype: int64
# Thorndale 2013 12 132    78291
# Name: 12, dtype: int64
# Thorndale 2014 12 132    79466
# Name: 12, dtype: int64
# Thorndale 2015 12 133    80717
# Name: 12, dtype: int64
# Thorndale 2016 12 133    77966
# Name: 12, dtype: int64
# Thorndale 2017 12 133    75206
# Name: 12, dtype: int64
# Thorndale 2018 12 133    0
# Name: 12, dtype: int64
# Thorndale 2019 12 132    67131
# Name: 12, dtype: int64
# UIC-Halsted 2013 1 133    133498
# Name: 1, dtype: int64
# UIC-Halsted 2014 1 133    131804
# Name: 1, dtype: int64
# UIC-Halsted 2015 1 134    129237
# Name: 1, dtype: int64
# UIC-Halsted 2016 1 134    138126
# Name: 1, dtype: int64
# UIC-Halsted 2017 1 134    145715
# Name: 1, dtype: int64
# UIC-Halsted 2018 1 134    127010
# Name: 1, dtype: int64
# UIC-Halsted 2019 1 133    120000
# Name: 1, dtype: int64
# UIC-Halsted 2013 2 133    160232
# Name: 2, dtype: int64
# UIC-Halsted 2014 2 133    159442
# Name: 2, dtype: int64
# UIC-Halsted 2015 2 134    148153
# Name: 2, dtype: int64
# UIC-Halsted 2016 2 134    170623
# Name: 2, dtype: int64
# UIC-Halsted 2017 2 134    159132
# Name: 2, dtype: int64
# UIC-Halsted 2018 2 134    154883
# Name: 2, dtype: int64
# UIC-Halsted 2019 2 133    163805
# Name: 2, dtype: int64
# UIC-Halsted 2013 3 133    150883
# Name: 3, dtype: int64
# UIC-Halsted 2014 3 133    156023
# Name: 3, dtype: int64
# UIC-Halsted 2015 3 134    147237
# Name: 3, dtype: int64
# UIC-Halsted 2016 3 134    164142
# Name: 3, dtype: int64
# UIC-Halsted 2017 3 134    157200
# Name: 3, dtype: int64
# UIC-Halsted 2018 3 134    152779
# Name: 3, dtype: int64
# UIC-Halsted 2019 3 133    148919
# Name: 3, dtype: int64
# UIC-Halsted 2013 4 133    171560
# Name: 4, dtype: int64
# UIC-Halsted 2014 4 133    173562
# Name: 4, dtype: int64
# UIC-Halsted 2015 4 134    159544
# Name: 4, dtype: int64
# UIC-Halsted 2016 4 134    169558
# Name: 4, dtype: int64
# UIC-Halsted 2017 4 134    157007
# Name: 4, dtype: int64
# UIC-Halsted 2018 4 134    161699
# Name: 4, dtype: int64
# UIC-Halsted 2019 4 133    170257
# Name: 4, dtype: int64
# UIC-Halsted 2013 5 133    114755
# Name: 5, dtype: int64
# UIC-Halsted 2014 5 133    110805
# Name: 5, dtype: int64
# UIC-Halsted 2015 5 134    96550
# Name: 5, dtype: int64
# UIC-Halsted 2016 5 134    96639
# Name: 5, dtype: int64
# UIC-Halsted 2017 5 134    98213
# Name: 5, dtype: int64
# UIC-Halsted 2018 5 134    111593
# Name: 5, dtype: int64
# UIC-Halsted 2019 5 133    111884
# Name: 5, dtype: int64
# UIC-Halsted 2013 6 133    95195
# Name: 6, dtype: int64
# UIC-Halsted 2014 6 133    93448
# Name: 6, dtype: int64
# UIC-Halsted 2015 6 134    92872
# Name: 6, dtype: int64
# UIC-Halsted 2016 6 134    94936
# Name: 6, dtype: int64
# UIC-Halsted 2017 6 134    94505
# Name: 6, dtype: int64
# UIC-Halsted 2018 6 134    88404
# Name: 6, dtype: int64
# UIC-Halsted 2019 6 133    89373
# Name: 6, dtype: int64
# UIC-Halsted 2013 7 133    108271
# Name: 7, dtype: int64
# UIC-Halsted 2014 7 133    102351
# Name: 7, dtype: int64
# UIC-Halsted 2015 7 134    97767
# Name: 7, dtype: int64
# UIC-Halsted 2016 7 134    92950
# Name: 7, dtype: int64
# UIC-Halsted 2017 7 134    90720
# Name: 7, dtype: int64
# UIC-Halsted 2018 7 134    91857
# Name: 7, dtype: int64
# UIC-Halsted 2019 7 133    96735
# Name: 7, dtype: int64
# UIC-Halsted 2013 8 133    121806
# Name: 8, dtype: int64
# UIC-Halsted 2014 8 133    118997
# Name: 8, dtype: int64
# UIC-Halsted 2015 8 134    120496
# Name: 8, dtype: int64
# UIC-Halsted 2016 8 134    133019
# Name: 8, dtype: int64
# UIC-Halsted 2017 8 134    114846
# Name: 8, dtype: int64
# UIC-Halsted 2018 8 134    0
# Name: 8, dtype: int64
# UIC-Halsted 2019 8 133    121219
# Name: 8, dtype: int64
# UIC-Halsted 2013 9 133    168815
# Name: 9, dtype: int64
# UIC-Halsted 2014 9 133    187470
# Name: 9, dtype: int64
# UIC-Halsted 2015 9 134    196646
# Name: 9, dtype: int64
# UIC-Halsted 2016 9 134    195648
# Name: 9, dtype: int64
# UIC-Halsted 2017 9 134    193684
# Name: 9, dtype: int64
# UIC-Halsted 2018 9 134    0
# Name: 9, dtype: int64
# UIC-Halsted 2019 9 133    200995
# Name: 9, dtype: int64
# UIC-Halsted 2013 10 133    211508
# Name: 10, dtype: int64
# UIC-Halsted 2014 10 133    202553
# Name: 10, dtype: int64
# UIC-Halsted 2015 10 134    210598
# Name: 10, dtype: int64
# UIC-Halsted 2016 10 134    200754
# Name: 10, dtype: int64
# UIC-Halsted 2017 10 134    206824
# Name: 10, dtype: int64
# UIC-Halsted 2018 10 134    0
# Name: 10, dtype: int64
# UIC-Halsted 2019 10 133    222190
# Name: 10, dtype: int64
# UIC-Halsted 2013 11 133    172468
# Name: 11, dtype: int64
# UIC-Halsted 2014 11 133    156045
# Name: 11, dtype: int64
# UIC-Halsted 2015 11 134    173267
# Name: 11, dtype: int64
# UIC-Halsted 2016 11 134    179153
# Name: 11, dtype: int64
# UIC-Halsted 2017 11 134    177054
# Name: 11, dtype: int64
# UIC-Halsted 2018 11 134    0
# Name: 11, dtype: int64
# UIC-Halsted 2019 11 133    177206
# Name: 11, dtype: int64
# UIC-Halsted 2013 12 133    106312
# Name: 12, dtype: int64
# UIC-Halsted 2014 12 133    102608
# Name: 12, dtype: int64
# UIC-Halsted 2015 12 134    104443
# Name: 12, dtype: int64
# UIC-Halsted 2016 12 134    90009
# Name: 12, dtype: int64
# UIC-Halsted 2017 12 134    108064
# Name: 12, dtype: int64
# UIC-Halsted 2018 12 134    0
# Name: 12, dtype: int64
# UIC-Halsted 2019 12 133    106456
# Name: 12, dtype: int64
# Washington/Dearborn 2013 1 134    219972
# Name: 1, dtype: int64
# Washington/Dearborn 2014 1 134    252944
# Name: 1, dtype: int64
# Washington/Dearborn 2015 1 135    257556
# Name: 1, dtype: int64
# Washington/Dearborn 2016 1 135    275435
# Name: 1, dtype: int64
# Washington/Dearborn 2017 1 135    293173
# Name: 1, dtype: int64
# Washington/Dearborn 2018 1 135    300772
# Name: 1, dtype: int64
# Washington/Dearborn 2019 1 134    300816
# Name: 1, dtype: int64
# Washington/Dearborn 2013 2 134    207478
# Name: 2, dtype: int64
# Washington/Dearborn 2014 2 134    256430
# Name: 2, dtype: int64
# Washington/Dearborn 2015 2 135    249049
# Name: 2, dtype: int64
# Washington/Dearborn 2016 2 135    286103
# Name: 2, dtype: int64
# Washington/Dearborn 2017 2 135    279944
# Name: 2, dtype: int64
# Washington/Dearborn 2018 2 135    282264
# Name: 2, dtype: int64
# Washington/Dearborn 2019 2 134    303071
# Name: 2, dtype: int64
# Washington/Dearborn 2013 3 134    234883
# Name: 3, dtype: int64
# Washington/Dearborn 2014 3 134    288782
# Name: 3, dtype: int64
# Washington/Dearborn 2015 3 135    299225
# Name: 3, dtype: int64
# Washington/Dearborn 2016 3 135    324653
# Name: 3, dtype: int64
# Washington/Dearborn 2017 3 135    331025
# Name: 3, dtype: int64
# Washington/Dearborn 2018 3 135    333086
# Name: 3, dtype: int64
# Washington/Dearborn 2019 3 134    344872
# Name: 3, dtype: int64
# Washington/Dearborn 2013 4 134    238357
# Name: 4, dtype: int64
# Washington/Dearborn 2014 4 134    278638
# Name: 4, dtype: int64
# Washington/Dearborn 2015 4 135    292025
# Name: 4, dtype: int64
# Washington/Dearborn 2016 4 135    303147
# Name: 4, dtype: int64
# Washington/Dearborn 2017 4 135    303479
# Name: 4, dtype: int64
# Washington/Dearborn 2018 4 135    314872
# Name: 4, dtype: int64
# Washington/Dearborn 2019 4 134    342058
# Name: 4, dtype: int64
# Washington/Dearborn 2013 5 134    247608
# Name: 5, dtype: int64
# Washington/Dearborn 2014 5 134    286495
# Name: 5, dtype: int64
# Washington/Dearborn 2015 5 135    296065
# Name: 5, dtype: int64
# Washington/Dearborn 2016 5 135    313541
# Name: 5, dtype: int64
# Washington/Dearborn 2017 5 135    331492
# Name: 5, dtype: int64
# Washington/Dearborn 2018 5 135    337697
# Name: 5, dtype: int64
# Washington/Dearborn 2019 5 134    358542
# Name: 5, dtype: int64
# Washington/Dearborn 2013 6 134    271634
# Name: 6, dtype: int64
# Washington/Dearborn 2014 6 134    293678
# Name: 6, dtype: int64
# Washington/Dearborn 2015 6 135    323356
# Name: 6, dtype: int64
# Washington/Dearborn 2016 6 135    339418
# Name: 6, dtype: int64
# Washington/Dearborn 2017 6 135    355223
# Name: 6, dtype: int64
# Washington/Dearborn 2018 6 135    348741
# Name: 6, dtype: int64
# Washington/Dearborn 2019 6 134    362993
# Name: 6, dtype: int64
# Washington/Dearborn 2013 7 134    296869
# Name: 7, dtype: int64
# Washington/Dearborn 2014 7 134    311158
# Name: 7, dtype: int64
# Washington/Dearborn 2015 7 135    340362
# Name: 7, dtype: int64
# Washington/Dearborn 2016 7 135    329617
# Name: 7, dtype: int64
# Washington/Dearborn 2017 7 135    338347
# Name: 7, dtype: int64
# Washington/Dearborn 2018 7 135    350474
# Name: 7, dtype: int64
# Washington/Dearborn 2019 7 134    375766
# Name: 7, dtype: int64
# Washington/Dearborn 2013 8 134    294865
# Name: 8, dtype: int64
# Washington/Dearborn 2014 8 134    295912
# Name: 8, dtype: int64
# Washington/Dearborn 2015 8 135    314693
# Name: 8, dtype: int64
# Washington/Dearborn 2016 8 135    335718
# Name: 8, dtype: int64
# Washington/Dearborn 2017 8 135    358084
# Name: 8, dtype: int64
# Washington/Dearborn 2018 8 135    0
# Name: 8, dtype: int64
# Washington/Dearborn 2019 8 134    371610
# Name: 8, dtype: int64
# Washington/Dearborn 2013 9 134    275025
# Name: 9, dtype: int64
# Washington/Dearborn 2014 9 134    286907
# Name: 9, dtype: int64
# Washington/Dearborn 2015 9 135    313378
# Name: 9, dtype: int64
# Washington/Dearborn 2016 9 135    317019
# Name: 9, dtype: int64
# Washington/Dearborn 2017 9 135    327611
# Name: 9, dtype: int64
# Washington/Dearborn 2018 9 135    0
# Name: 9, dtype: int64
# Washington/Dearborn 2019 9 134    345935
# Name: 9, dtype: int64
# Washington/Dearborn 2013 10 134    306273
# Name: 10, dtype: int64
# Washington/Dearborn 2014 10 134    309950
# Name: 10, dtype: int64
# Washington/Dearborn 2015 10 135    329559
# Name: 10, dtype: int64
# Washington/Dearborn 2016 10 135    335944
# Name: 10, dtype: int64
# Washington/Dearborn 2017 10 135    353740
# Name: 10, dtype: int64
# Washington/Dearborn 2018 10 135    0
# Name: 10, dtype: int64
# Washington/Dearborn 2019 10 134    390665
# Name: 10, dtype: int64
# Washington/Dearborn 2013 11 134    287455
# Name: 11, dtype: int64
# Washington/Dearborn 2014 11 134    273137
# Name: 11, dtype: int64
# Washington/Dearborn 2015 11 135    299714
# Name: 11, dtype: int64
# Washington/Dearborn 2016 11 135    330452
# Name: 11, dtype: int64
# Washington/Dearborn 2017 11 135    336327
# Name: 11, dtype: int64
# Washington/Dearborn 2018 11 135    0
# Name: 11, dtype: int64
# Washington/Dearborn 2019 11 134    346886
# Name: 11, dtype: int64
# Washington/Dearborn 2013 12 134    295484
# Name: 12, dtype: int64
# Washington/Dearborn 2014 12 134    297768
# Name: 12, dtype: int64
# Washington/Dearborn 2015 12 135    318676
# Name: 12, dtype: int64
# Washington/Dearborn 2016 12 135    313908
# Name: 12, dtype: int64
# Washington/Dearborn 2017 12 135    314314
# Name: 12, dtype: int64
# Washington/Dearborn 2018 12 135    0
# Name: 12, dtype: int64
# Washington/Dearborn 2019 12 134    333734
# Name: 12, dtype: int64
# Washington/Wabash 2013 1 Series([], Name: 1, dtype: int64)
# Washington/Wabash 2014 1 Series([], Name: 1, dtype: int64)
# Washington/Wabash 2015 1 Series([], Name: 1, dtype: int64)
# Washington/Wabash 2016 1 Series([], Name: 1, dtype: int64)
# Washington/Wabash 2017 1 136    242410
# Name: 1, dtype: int64
# Washington/Wabash 2018 1 136    225310
# Name: 1, dtype: int64
# Washington/Wabash 2019 1 135    215300
# Name: 1, dtype: int64
# Washington/Wabash 2013 2 Series([], Name: 2, dtype: int64)
# Washington/Wabash 2014 2 Series([], Name: 2, dtype: int64)
# Washington/Wabash 2015 2 Series([], Name: 2, dtype: int64)
# Washington/Wabash 2016 2 Series([], Name: 2, dtype: int64)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-9b15a75c26d2> in <module>
#       2     for month in range(1,13):
#       3         for year in range(2013,2020):
# ----> 4             ridership = riders[year][(riders[year]['stationame'] == station)][str(month)].astype(int)
#       5             print(station, year, month, ridership)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors)
#     623             vals1d = values.ravel()
#     624             try:
# --> 625                 values = astype_nansafe(vals1d, dtype, copy=True)
#     626             except (ValueError, TypeError):
#     627                 # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     866
#     867         if not np.isfinite(arr).all():
# --> 868             raise ValueError("Cannot convert non-finite values (NA or inf) to integer")
#     869
#     870     elif is_object_dtype(arr):
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %%
years = [2013, 2014, 2015, 2016, 2017, 2018, 2019]

for station in riders2020['stationame']:
    for month in range(1,13):
        x = years
        y = []
        for year in years:
            riders[year][(riders[year]['stationame'] == station)][str(month)]
        ds = pd.DataFrame(list(zip(x,y)), columns = ['year','riders'])
        X = ds.iloc[:, 0].values.reshape(-1, 1)  # values converts it into a numpy array
        Y = ds.iloc[:, 1].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
        regressor = LinearRegression()  # create object for the class
        regressor.fit(X, Y)  # perform linear regression
        Y_pred = regressor.predict(X)  # make predictions
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-3e7893d5056d> in <module>
#      11         Y = ds.iloc[:, 1].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
#      12         regressor = LinearRegression()  # create object for the class
# ---> 13         regressor.fit(X, Y)  # perform linear regression
#      14         Y_pred = regressor.predict(X)  # make predictions
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     794         raise ValueError("y cannot be None")
#     795
# --> 796     X = check_array(X, accept_sparse=accept_sparse,
#     797                     accept_large_sparse=accept_large_sparse,
#     798                     dtype=dtype, order=order, copy=copy,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     649         n_samples = _num_samples(array)
#     650         if n_samples < ensure_min_samples:
# --> 651             raise ValueError("Found array with %d sample(s) (shape=%s) while a"
#     652                              " minimum of %d is required%s."
#     653                              % (n_samples, array.shape, ensure_min_samples,
#
# ValueError: Found array with 0 sample(s) (shape=(0, 1)) while a minimum of 1 is required.

# %%
years = [2013, 2014, 2015, 2016, 2017, 2018, 2019]

for station in riders2020['stationame']:
    for month in range(1,13):
        x = years
        y = []
        for year in years:
            riders[year][(riders[year]['stationame'] == station)][str(month)]
        ds = pd.DataFrame(list(zip(x,y)), columns = ['year','riders'])
        X = ds.iloc[:, 0].values.reshape(-1, 1)  # values converts it into a numpy array
        Y = ds.iloc[:, 1].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
        regressor = LinearRegression()  # create object for the class
        regressor.fit(X, Y)  # perform linear regression
        Y_pred = regressor.predict(X)  # make predictions
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-3e7893d5056d> in <module>
#      11         Y = ds.iloc[:, 1].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
#      12         regressor = LinearRegression()  # create object for the class
# ---> 13         regressor.fit(X, Y)  # perform linear regression
#      14         Y_pred = regressor.predict(X)  # make predictions
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     794         raise ValueError("y cannot be None")
#     795
# --> 796     X = check_array(X, accept_sparse=accept_sparse,
#     797                     accept_large_sparse=accept_large_sparse,
#     798                     dtype=dtype, order=order, copy=copy,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     649         n_samples = _num_samples(array)
#     650         if n_samples < ensure_min_samples:
# --> 651             raise ValueError("Found array with %d sample(s) (shape=%s) while a"
#     652                              " minimum of %d is required%s."
#     653                              % (n_samples, array.shape, ensure_min_samples,
#
# ValueError: Found array with 0 sample(s) (shape=(0, 1)) while a minimum of 1 is required.

# %%
for station in allrides['station_name']:
    for month in allrides['month']:
        ds = pd.DataFrame(list(zip(allrides['year'], allrides['riders'])),columns = ['indep','dep'])
        X = ds.iloc[:, 0].values.reshape(-1, 1)  # values converts it into a numpy array
        Y = ds.iloc[:, 1].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
        regressor = LinearRegression()  # create object for the class
        regressor.fit(X, Y)  # perform linear regression
        Y_pred = regressor.predict(X)  # make predictions
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-80b1d6e8961b> in <module>
#       5         Y = ds.iloc[:, 1].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
#       6         regressor = LinearRegression()  # create object for the class
# ----> 7         regressor.fit(X, Y)  # perform linear regression
#       8         Y_pred = regressor.predict(X)  # make predictions
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     794         raise ValueError("y cannot be None")
#     795
# --> 796     X = check_array(X, accept_sparse=accept_sparse,
#     797                     accept_large_sparse=accept_large_sparse,
#     798                     dtype=dtype, order=order, copy=copy,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     643
#     644         if force_all_finite:
# --> 645             _assert_all_finite(array,
#     646                                allow_nan=force_all_finite == 'allow-nan')
#     647
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#      95                 not allow_nan and not np.isfinite(X).all()):
#      96             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 97             raise ValueError(
#      98                     msg_err.format
#      99                     (type_err,
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
