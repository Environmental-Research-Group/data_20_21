# %%
import pandas as pd
import numpy as np

# %%
TrafficCounts = pd.read_json("https://data.cityofchicago.org/resource/pfsx-4n4m.json")

# %%
tc_head = TrafficCounts.head(5)
tc_description = TrafficCounts.describe()
tc_shape = TrafficCounts.shape
tc_head
# Out:
#      id traffic_volume_count_location_address    street  \
# 0   414                             5838 West   Lake St
# 1   176                              320 East   76th St
# 2   715                             835 North  Clark St
# 3   316                              125 East   24th St
# 4  1294                             2924 East  130th St
#
#               date_of_count  total_passing_vehicle_volume  \
# 0  2006-11-14T08:00:00.000Z                          7100
# 1  2006-03-28T08:00:00.000Z                          8600
# 2  2006-09-20T07:00:00.000Z                         16500
# 3  2006-03-30T08:00:00.000Z                           700
# 4  2006-08-29T07:00:00.000Z                          4200
#
#   vehicle_volume_by_each_direction_of_traffic   latitude  longitude  \
# 0         East Bound: 3600 / West Bound: 3500  41.887904 -87.771064
# 1         East Bound: 3800 / West Bound: 4800  41.756542 -87.617335
# 2     South Bound: 16500/ Oneway South Bound   41.897747 -87.631275
# 3           East Bound: 400 / West Bound: 300  41.849302 -87.622658
# 4         East Bound: 2300 / West Bound: 1900  41.659177 -87.552112
#
#                                             location  \
# 0  {'latitude': '41.887904', 'longitude': '-87.77...
# 1  {'latitude': '41.756542', 'longitude': '-87.61...
# 2  {'latitude': '41.897747', 'longitude': '-87.63...
# 3  {'latitude': '41.849302', 'longitude': '-87.62...
# 4  {'latitude': '41.659177', 'longitude': '-87.55...
#
#    :@computed_region_rpca_8um6  :@computed_region_vrxf_vc4k  \
# 0                         32.0                         26.0
# 1                         61.0                         67.0
# 2                         54.0                         37.0
# 3                         40.0                         34.0
# 4                         26.0                         52.0
#
#    :@computed_region_6mkv_f3dw  :@computed_region_bdys_3d7i  \
# 0                        22216                        672.0
# 1                        21546                        475.0
# 2                        14926                        310.0
# 3                        21194                        193.0
# 4                        22250                        586.0
#
#    :@computed_region_43wa_7qmu  :@computed_region_awaf_s7ux
# 0                          7.0                         52.0
# 1                         32.0                         31.0
# 2                         11.0                         22.0
# 3                          9.0                         48.0
# 4                         47.0                         47.0

# %%
tc_description
# Out:
#                 id  total_passing_vehicle_volume     latitude    longitude  \
# count  1000.000000                   1000.000000  1000.000000  1000.000000
# mean    699.923000                  19284.200000    41.848757   -87.669140
# std     398.137213                  12576.120593     0.083566     0.060015
# min       1.000000                    700.000000    41.651861   -87.846567
# 25%     359.500000                  11100.000000    41.779920   -87.705867
# 50%     695.500000                  17100.000000    41.870047   -87.660550
# 75%    1047.250000                  24025.000000    41.907736   -87.628316
# max    1382.000000                 165200.000000    42.017888   -87.531879
#
#        :@computed_region_rpca_8um6  :@computed_region_vrxf_vc4k  \
# count                   988.000000                   988.000000
# mean                     32.763158                    37.939271
# std                      17.532387                    19.342442
# min                       1.000000                     1.000000
# 25%                      19.000000                    25.000000
# 50%                      35.000000                    37.000000
# 75%                      45.250000                    55.000000
# max                      61.000000                    77.000000
#
#        :@computed_region_6mkv_f3dw  :@computed_region_bdys_3d7i  \
# count                  1000.000000                   987.000000
# mean                  18445.100000                   369.108409
# std                    5737.297131                   237.816601
# min                    4299.000000                     1.000000
# 25%                   14920.000000                   130.000000
# 50%                   21538.000000                   368.000000
# 75%                   22212.000000                   578.500000
# max                   26633.000000                   800.000000
#
#        :@computed_region_43wa_7qmu  :@computed_region_awaf_s7ux
# count                   988.000000                   988.000000
# mean                     26.779352                    28.535425
# std                      14.625272                    14.927035
# min                       1.000000                     1.000000
# 25%                      13.000000                    16.000000
# 50%                      28.000000                    28.000000
# 75%                      38.000000                    41.250000
# max                      50.000000                    53.000000
